# %% [markdown]
# # Create and visualize basic data

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import os
#!pip install combat
from combat.pycombat import pycombat
import matplotlib.pyplot as plt
import utils as utils

    
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# GDSC
gdsc_data_path = 'data/GDSC1_fitted_dose_response_25Feb20.xlsx'
gdsc_rma_proc_basalexp_path = 'data/Cell_line_RMA_proc_basalExp.txt'

# Beat-AML
beat_aml_rnaseq_path = 'data/beat_aml_rnaseq.csv'
beat_aml_auc_path = 'data/beat_aml_aucs.csv'

# %% [markdown]
# ## GDSC data

# %%
gdsc_data = pd.read_excel(gdsc_data_path)
gdsc_data.head()
# Out:
#   DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0   GDSC1             281       12974350     683665         MC-CAR
# 1   GDSC1             281       12975300     684055            ES3
# 2   GDSC1             281       12975647     684057            ES5
# 3   GDSC1             281       12975980     684059            ES7
# 4   GDSC1             281       12976330     684062          EW-11
#
#   SANGER_MODEL_ID     TCGA_DESC  DRUG_ID  DRUG_NAME PUTATIVE_TARGET  \
# 0       SIDM00636            MM        1  Erlotinib            EGFR
# 1       SIDM00265  UNCLASSIFIED        1  Erlotinib            EGFR
# 2       SIDM00263  UNCLASSIFIED        1  Erlotinib            EGFR
# 3       SIDM00269  UNCLASSIFIED        1  Erlotinib            EGFR
# 4       SIDM00203  UNCLASSIFIED        1  Erlotinib            EGFR
#
#      PATHWAY_NAME  COMPANY_ID WEBRELEASE  MIN_CONC  MAX_CONC   LN_IC50  \
# 0  EGFR signaling        1045          Y  0.007813       2.0  2.395685
# 1  EGFR signaling        1045          Y  0.007813       2.0  3.140923
# 2  EGFR signaling        1045          Y  0.007813       2.0  3.968757
# 3  EGFR signaling        1045          Y  0.007813       2.0  2.692768
# 4  EGFR signaling        1045          Y  0.007813       2.0  2.478678
#
#         AUC      RMSE   Z_SCORE
# 0  0.982114  0.022521 -0.189576
# 1  0.984816  0.031840  0.508635
# 2  0.985693  0.026052  1.284229
# 3  0.972699  0.110056  0.088760
# 4  0.944462  0.087011 -0.111820

# %%
gdsc_rma_proc_basalexp = pd.read_csv(gdsc_rma_proc_basalexp_path,sep='\t')
gdsc_rma_proc_basalexp.head()
# Out:
#   GENE_SYMBOLS                                         GENE_title  \
# 0       TSPAN6       tetraspanin 6 [Source:HGNC Symbol;Acc:11858]
# 1         TNMD         tenomodulin [Source:HGNC Symbol;Acc:17757]
# 2         DPM1  dolichyl-phosphate mannosyltransferase polypep...
# 3        SCYL3  SCY1-like 3 (S. cerevisiae) [Source:HGNC Symbo...
# 4     C1orf112  chromosome 1 open reading frame 112 [Source:HG...
#
#    DATA.906826  DATA.687983  DATA.910927  DATA.1240138  DATA.1240139  \
# 0     7.632023     7.548671     8.712338      7.797142      7.729268
# 1     2.964585     2.777716     2.643508      2.817923      2.957739
# 2    10.379553    11.807341     9.880733      9.883471     10.418840
# 3     3.614794     4.066887     3.956230      4.063701      4.341500
# 4     3.380681     3.732485     3.236620      3.558414      3.840373
#
#    DATA.906792  DATA.910688  DATA.1240135  ...  DATA.753584  DATA.907044  \
# 0     7.074533     3.285198      6.961606  ...     7.105637     3.236503
# 1     2.889677     2.828203      2.874751  ...     2.798847     2.745137
# 2     9.773987    10.264385     10.205931  ...    10.486486    10.442951
# 3     4.270903     5.968168      3.715033  ...     3.696835     4.624013
# 4     3.815055     3.011867      3.268449  ...     3.726833     3.947744
#
#    DATA.998184  DATA.908145  DATA.1659787  DATA.1298157  DATA.1480372  \
# 0     3.038892     8.373223      6.932178      8.441628      8.422922
# 1     2.976406     2.852552      2.622630      2.639276      2.879890
# 2    10.311962    10.454830     10.418475     11.463742     10.557777
# 3     4.348524     3.858121      3.947561      4.425849      3.550390
# 4     3.806584     3.196988      3.814831      4.384732      4.247189
#
#    DATA.1298533  DATA.930299  DATA.905954.1
# 0      8.089255     3.112333       7.153127
# 1      2.521169     2.870468       2.834285
# 2     10.792750     9.873902      10.788218
# 3      4.443337     4.266828       4.100493
# 4      3.071359     3.230197       3.435795
#
# [5 rows x 1020 columns]

# %% [markdown]
# ### Extract inchi, inchi-key, smiles for compounds

# %%
unique_compounds = list(np.unique(gdsc_data['DRUG_NAME']))
use_fields = ['inchi','inchikey','canonical_smiles']
save_path = 'data/gdsc_compound_inchi_smiles.csv'
flag_redo = False
if not os.path.exists(save_path) or flag_redo:
    compound_dict = {'DRUG_NAME':[]}
    for i in tqdm(np.arange(len(unique_compounds))):
        cur_compound = unique_compounds[i]
        tmp_dict = utils.get_prop_dict_for_compound(cur_compound)
        for field in use_fields:
            if field not in compound_dict:
                compound_dict[field] = []
            try:
                cur_val = tmp_dict[field]
                compound_dict[field].append(cur_val)
            except:
                compound_dict[field].append(np.nan)
        compound_dict['DRUG_NAME'].append(cur_compound)
    pd.DataFrame(compound_dict).to_csv(save_path)

# %%
gdsc_smiles_data_path = 'data/gdsc_compound_inchi_smiles.csv'
gdsc_smiles_data = pd.read_csv(gdsc_smiles_data_path)
not_nan_instances = np.sum(np.array(gdsc_smiles_data['canonical_smiles'],dtype=np.str) != 'nan')
print('data for ' + str(not_nan_instances) + ' compounds [of ' +\
      str(gdsc_smiles_data.shape[0]) + ']')
gdsc_smiles_data.head()
# Out:
# data for 282 compounds [of 345]
#    Unnamed: 0          DRUG_NAME  \
# 0           0  (5Z)-7-Oxozeaenol
# 1           1     5-Fluorouracil
# 2           2           A-443654
# 3           3           A-770041
# 4           4            A-83-01
#
#                                                inchi  \
# 0  InChI=1S/C19H22O7/c1-11-5-3-7-14(20)18(23)15(2...
# 1  InChI=1S/C4H3FN2O2/c5-2-1-6-4(9)7-3(2)8/h1H,(H...
# 2  InChI=1S/C24H23N5O/c1-15-22-10-16(6-7-24(22)29...
# 3  InChI=1S/C34H39N9O3/c1-21(44)41-14-16-42(17-15...
# 4  InChI=1S/C25H19N5S/c1-17-8-7-13-23(27-17)24-21...
#
#                       inchikey  \
# 0  NEQZWEXWOFPKOT-BYRRXHGESA-N
# 1  GHASVSINZRGABV-UHFFFAOYSA-N
# 2  YWTBGJGMTBHQTM-IBGZPJMESA-N
# 3  ZMNWFTYYYCSSTF-UHFFFAOYSA-N
# 4  HIJMSZGHKQPPJS-UHFFFAOYSA-N
#
#                                     canonical_smiles
# 0  CC1CC=CC(=O)C(C(CC=CC2=C(C(=CC(=C2)OC)O)C(=O)O...
# 1                               C1=C(C(=O)NC(=O)N1)F
# 2  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CNC5=...
# 3  CC(=O)N1CCN(CC1)C2CCC(CC2)N3C4=NC=NC(=C4C(=N3)...
# 4  CC1=NC(=CC=C1)C2=NN(C=C2C3=CC=NC4=CC=CC=C34)C(...

# %% [markdown]
# ## Beat-AML data

# %%
beat_aml_rnaseq = pd.read_csv(beat_aml_rnaseq_path)
beat_aml_rnaseq.head()
# Out:
#               Gene    Symbol  13-00098  13-00118  13-00149  13-00157  \
# 0  ENSG00000000003    TSPAN6 -4.283015 -2.579843 -2.038435 -4.283015
# 1  ENSG00000000005      TNMD -4.283015 -4.283015 -4.283015 -4.283015
# 2  ENSG00000000419      DPM1  5.293654  4.592634  4.898245  5.029179
# 3  ENSG00000000457     SCYL3  3.953188  4.675118  4.524586  5.279625
# 4  ENSG00000000460  C1orf112  4.557584  3.644984  4.723479  3.101024
#
#    13-00160  13-00165  13-00166  13-00186  ...  16-01191  16-01201  16-01216  \
# 0  0.524850 -1.702019 -1.988387 -2.825933  ... -1.078500  0.176421 -0.515411
# 1 -4.283015 -4.283015 -4.283015 -4.283015  ... -4.283015 -4.283015 -4.283015
# 2  5.113583  4.766740  4.935838  4.830074  ...  4.436039  4.955578  5.098456
# 3  3.076162  4.989021  5.354993  4.607610  ...  4.224279  4.739571  3.756682
# 4  3.697294  3.642136  2.988082  3.838717  ...  3.415510  3.516894  2.527958
#
#    16-01219  16-01223  16-01225  16-01237  16-01254  16-01262  16-01270
# 0 -2.872676  0.104199 -1.255918 -1.735680 -3.048100 -2.370723 -2.306173
# 1 -4.283015 -4.283015 -4.283015 -4.283015 -4.283015 -4.283015 -4.283015
# 2  4.839901  4.926395  5.169932  5.278429  4.686827  5.076239  4.054189
# 3  4.382689  4.399412  4.572803  2.866336  4.428773  4.044699  4.022405
# 4  4.080170  2.709617  4.044730  2.290900  3.405635  3.120103  2.805191
#
# [5 rows x 215 columns]

# %%
beat_aml_auc = pd.read_csv(beat_aml_auc_path)
beat_aml_auc.head()
# Out:
#      lab_id              inhibitor         auc
# 0  13-00098  17-AAG (Tanespimycin)  230.223782
# 1  13-00118  17-AAG (Tanespimycin)  217.469453
# 2  13-00149  17-AAG (Tanespimycin)  206.326341
# 3  13-00157  17-AAG (Tanespimycin)  140.603252
# 4  13-00160  17-AAG (Tanespimycin)  138.379558

# %% [markdown]
# ### Extract inchi, inchi-key, smiles for compounds

# %%
unique_compounds = list(np.unique(beat_aml_auc['inhibitor']))
use_fields = ['inchi','inchikey','canonical_smiles']
save_path = 'data/beat_aml_inhibitor_inchi_smiles.csv'
flag_redo = False
if not os.path.exists(save_path) or flag_redo:
    compound_beat_aml_dict = {'inhibitor':[]}
    for i in tqdm(np.arange(len(unique_compounds))):
        cur_compound = unique_compounds[i]
        tmp_dict = utils.get_prop_dict_for_compound(cur_compound)
        for field in use_fields:
            if field not in compound_beat_aml_dict:
                compound_beat_aml_dict[field] = []
            try:
                cur_val = tmp_dict[field]
                compound_beat_aml_dict[field].append(cur_val)
            except:
                compound_beat_aml_dict[field].append(np.nan)
        compound_beat_aml_dict['inhibitor'].append(cur_compound)
    pd.DataFrame(compound_beat_aml_dict).to_csv(save_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=122.0), HTML(value='')))

# %%
beat_aml_smiles_data_path = 'data/beat_aml_inhibitor_inchi_smiles.csv'
beat_aml_smiles_data = pd.read_csv(beat_aml_smiles_data_path)
not_nan_instances = np.sum(np.array(beat_aml_smiles_data['canonical_smiles'],dtype=np.str) != 'nan')
print('data for ' + str(not_nan_instances) + ' compounds [of ' +\
      str(beat_aml_smiles_data.shape[0]) + ']')
beat_aml_smiles_data.head()
# Out:
# data for 109 compounds [of 122]
#    Unnamed: 0              inhibitor  \
# 0           0  17-AAG (Tanespimycin)
# 1           1               A-674563
# 2           2                ABT-737
# 3           3                 AT7519
# 4           4                AZD1480
#
#                                                inchi  \
# 0  InChI=1S/C31H43N3O8/c1-8-12-33-26-21-13-17(2)1...
# 1  InChI=1S/C22H22N4O/c1-15-21-11-17(7-8-22(21)26...
# 2  InChI=1S/C42H45ClN6O5S2/c1-46(2)23-22-35(30-55...
# 3  InChI=1S/C16H17Cl2N5O2/c17-10-2-1-3-11(18)13(1...
# 4  InChI=1S/C14H14ClFN8/c1-7-3-11(24-23-7)21-13-1...
#
#                       inchikey  \
# 0  AYUNIORJHRXIBJ-TXHRRWQRSA-N
# 1  BPNUQXPIQBZCMR-IBGZPJMESA-N
# 2  HPLNQCPCUACXLM-PGUFJCEWSA-N
# 3  OVPNQJVDAFNBDN-UHFFFAOYSA-N
# 4  PDOQBOJDRPLBQU-QMMMGPOBSA-N
#
#                                     canonical_smiles
# 0  CC1CC(C(C(C=C(C(C(C=CC=C(C(=O)NC2=CC(=O)C(=C(C...
# 1  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CC=CC...
# 2  CN(C)CCC(CSC1=CC=CC=C1)NC2=C(C=C(C=C2)S(=O)(=O...
# 3   C1CNCCC1NC(=O)C2=C(C=NN2)NC(=O)C3=C(C=CC=C3Cl)Cl
# 4    CC1=CC(=NN1)NC2=NC(=NC=C2Cl)NC(C)C3=NC=C(C=N3)F

# %% [markdown]
# ## Pancreas data

# %%
pancreas_drug_data_chemo = pd.read_excel('data/organoid_pancreas/S4_199398_2_supp_4775187_p95dln.xlsx',
                                  sheet_name = 1, header = 1)
print(pancreas_drug_data_chemo.shape)
pancreas_drug_data_chemo.head()
# Out:
# (66, 7)
#   Sample ID  Gemcitabine  Paclitaxel     SN-38      5-FU  Oxaliplatin  \
# 0       hF2     0.554358    0.712962  0.499950  0.782922     0.887246
# 1      hF23     0.523995    0.486711  0.547860  0.781999     0.820843
# 2      hF24     0.609942    0.742389  0.549167  0.671272     0.809528
# 3      hF27     0.677162    0.636766  0.567865  0.838669     0.852603
# 4      hF28     0.685010    0.662779  0.651442  0.861745     0.829213
#
#   Insensitive
# 0         NaN
# 1         NaN
# 2         NaN
# 3         YES
# 4         YES

# %%
pancreas_id_organoid_mapping_data = pd.read_excel('data/organoid_pancreas/S1_199398_2_supp_4775186_p95dln.xlsx',
                                                 sheet_name = 1, header = 1)
number_organoid_dict = dict()
nrs = list(pancreas_id_organoid_mapping_data['#'])
organoids = list(pancreas_id_organoid_mapping_data['Organoid'])
for i in range(len(nrs)):
    number_organoid_dict[nrs[i]] = organoids[i]
pancreas_id_organoid_mapping_data.head()
# Out:
#    #  Patient number Organoid      Site Type of Sample Sex   Age Race Stage  \
# 0  1               1      hT1  Pancreas      Resection   M  65.0    W    2B
# 1  2               2      hT3  Pancreas      Resection   M  35.0    W     4
# 2  3               3     hT25  Pancreas      Resection   F  61.0    W    2B
# 3  4               4     hT30  Pancreas      Resection   M  67.0    W    2B
# 4  5               5     hT44  Pancreas      Resection   M  68.0    W    2B
#
#   Tumor  ... WES passage  WGS  WGS passage RNAseq  RNAseq passage Chemo  \
# 0   YES  ...        25.0   NO          NaN    YES              17   YES
# 1   YES  ...        22.0   NO          NaN    YES           2, 12   YES
# 2   YES  ...        16.0   NO          NaN    YES               9   YES
# 3   YES  ...        32.0  YES          5.0    YES              31   YES
# 4   YES  ...        18.0   NO          NaN     NO             NaN   YES
#
#   Chemo passage Targeted Targeted passage Treatment prior to organoid
# 0        20, 22      YES           20, 22                          NO
# 1          5, 8      YES                8                         YES
# 2          6, 9      YES               15                          NO
# 3            29      YES               35                          NO
# 4             9      YES               17                          NO
#
# [5 rows x 22 columns]

# %%
sample_path = 'data/organoid_pancreas/sample.tsv'
sample_data = pd.read_csv(sample_path,sep='\t')
case_ids = list(sample_data['case_id'])
case_sub_ids = list(sample_data['case_submitter_id'])
case_id_sub_id_mapping = dict()
for i in range(len(case_ids)):
    case_id_sub_id_mapping[case_ids[i]] = case_sub_ids[i]
sample_data.head()
# Out:
#             project_id                               case_id  \
# 0  ORGANOID-PANCREATIC  aaece851-ced6-4816-9cf2-2fa506f2bc79
# 1  ORGANOID-PANCREATIC  aaece851-ced6-4816-9cf2-2fa506f2bc79
# 2  ORGANOID-PANCREATIC  d277d0dd-4be9-484f-ba57-2d9ac16c6736
# 3  ORGANOID-PANCREATIC  d277d0dd-4be9-484f-ba57-2d9ac16c6736
# 4  ORGANOID-PANCREATIC  1c49e2cd-e5f3-4fbd-a8f0-4714ed8fb818
#
#    case_submitter_id                             sample_id  \
# 0                 64  21646f4b-040f-4b44-82b4-2f621d7da457
# 1                 64  7d47c77f-d2a1-4950-b6b9-336d211fa67e
# 2                  6  a3f6c436-04c0-41eb-acb6-d320a2a321a8
# 3                  6  98faa1da-4b3b-41d2-b9eb-8ca30aa79dae
# 4                 44  544b8fb0-a8f8-4323-9c4c-da9ab460516f
#
#   sample_submitter_id biospecimen_anatomic_site biospecimen_laterality  \
# 0                S104                       '--                    '--
# 1                S191                       '--                    '--
# 2                S184                       '--                    '--
# 3                S133                       '--                    '--
# 4                 S78                       '--                    '--
#
#   catalog_reference  composition current_weight  ... sample_type_id  \
# 0               '--  3D Organoid            '--  ...            '--
# 1               '--  3D Organoid            '--  ...            '--
# 2               '--  3D Organoid            '--  ...            '--
# 3               '--  3D Organoid            '--  ...            '--
# 4               '--  3D Organoid            '--  ...            '--
#
#   shortest_dimension     state time_between_clamping_and_freezing  \
# 0                '--  released                                '--
# 1                '--  released                                '--
# 2                '--  released                                '--
# 3                '--  released                                '--
# 4                '--  released                                '--
#
#   time_between_excision_and_freezing tissue_collection_type tissue_type  \
# 0                                '--                    '--      Normal
# 1                                '--                    '--      Normal
# 2                                '--                    '--       Tumor
# 3                                '--                    '--       Tumor
# 4                                '--                    '--       Tumor
#
#   tumor_code tumor_code_id tumor_descriptor
# 0        '--           '--              '--
# 1        '--           '--              '--
# 2        '--           '--              '--
# 3        '--           '--              '--
# 4        '--           '--              '--
#
# [5 rows x 37 columns]

# %%
file_id_to_sample_path = 'data/organoid_pancreas/file_ids_to_sample_ids.txt'
file_id_to_sample_df = pd.read_csv(file_id_to_sample_path,sep='\t')
print(file_id_to_sample_df.shape)
file_id_to_sample_df.head()
# Out:
# (220, 4)
#                         cases.0.case_id                               file_id  \
# 0  d7f95afc-d9d9-497e-b7ba-cdaec4d300b4  cf80f48f-7ecb-41e5-8aae-726c69344ef8
# 1  08f63445-b236-4f97-b76a-2e5f4b3c5ff5  1ba65919-7c51-4dd8-8c34-c404fb6fc325
# 2  51ef4f43-6fb7-45c2-86fc-40c359af4ea8  18f62c21-1343-4e18-8d48-cd69a3300344
# 3  eee1adb4-f965-43a2-8037-ff706c37e0cc  0a0d2eee-27c9-4d14-9c25-899acde4a743
# 4  eee1adb4-f965-43a2-8037-ff706c37e0cc  54ec2e9f-d716-4b67-b10f-e85bc841e62e
#
#                                            file_name  \
# 0  84bba63e-1ed1-4832-9559-d7752cc741b2.htseq_cou...
# 1  40c3d223-a76c-4433-a18a-ca45d03072fa.FPKM-UQ.t...
# 2   9d26edab-7937-423c-8b5a-ac333211a29b.FPKM.txt.gz
# 3  cef42a2e-ed4c-488e-aba4-41aad7bc52f9.rna_seq.s...
# 4  cdd8996e-fb92-4499-83fa-ef393afbe86c.FPKM-UQ.t...
#
#                                      id
# 0  cf80f48f-7ecb-41e5-8aae-726c69344ef8
# 1  1ba65919-7c51-4dd8-8c34-c404fb6fc325
# 2  18f62c21-1343-4e18-8d48-cd69a3300344
# 3  0a0d2eee-27c9-4d14-9c25-899acde4a743
# 4  54ec2e9f-d716-4b67-b10f-e85bc841e62e

# %%
file_name_organid_dict = dict()
filenames = list(file_id_to_sample_df['file_name'])
ids       = list(file_id_to_sample_df['cases.0.case_id'])
for i in range(len(filenames)):
    file_name_organid_dict[filenames[i]] = number_organoid_dict[case_id_sub_id_mapping[ids[i]]]

# %%
file_name_organid_dict
# Out:
# {'84bba63e-1ed1-4832-9559-d7752cc741b2.htseq_counts.txt.gz': 'hT96',
#  '40c3d223-a76c-4433-a18a-ca45d03072fa.FPKM-UQ.txt.gz': 'hM17D',
#  '9d26edab-7937-423c-8b5a-ac333211a29b.FPKM.txt.gz': 'hT108',
#  'cef42a2e-ed4c-488e-aba4-41aad7bc52f9.rna_seq.star_gene_counts.tsv.gz': 'hM1A',
#  'cdd8996e-fb92-4499-83fa-ef393afbe86c.FPKM-UQ.txt.gz': 'hM1A',
#  '80b9fcf4-185c-4e52-bcff-8ab52ab4bfa5.htseq_counts.txt.gz': 'hM19A',
#  '71d2419c-9d19-400c-95cd-c5ad9ec0d69b.rna_seq.star_gene_counts.tsv.gz': 'hT134',
#  '1e7dc767-94e5-416f-92eb-bd32720f5a5b.rna_seq.star_gene_counts.tsv.gz': 'hM1A',
#  'c92f3dc4-24ea-457b-b90a-d6d599b14a73.rna_seq.star_gene_counts.tsv.gz': 'hF3',
#  '8bae4355-1fce-4604-84e4-f57937445d10.rna_seq.star_gene_counts.tsv.gz': 'hM19D',
#  '8236bc9d-2156-4991-a5eb-223e02229b3a.FPKM.txt.gz': 'hM1A',
#  '9c110cd2-aca9-4fa4-8035-193554239aac.htseq_counts.txt.gz': 'hT106',
#  '84bba63e-1ed1-4832-9559-d7752cc741b2.FPKM-UQ.txt.gz': 'hT96',
#  'fbaec595-23e3-43cf-aa61-94cab5b8d4be.rna_seq.star_gene_counts.tsv.gz': 'hF44',
#  'bc06ad7f-7af9-4e8c-8bbe-908faf0d7edc.htseq_counts.txt.gz': 'hF3',
#  'cdd8996e-fb92-4499-83fa-ef393afbe86c.htseq_counts.txt.gz': 'hM1A',
#  'cdd8996e-fb92-4499-83fa-ef393afbe86c.FPKM.txt.gz': 'hM1A',
#  'f7b2476f-2087-4e10-8571-bd8e1fcbb835.FPKM.txt.gz': 'hM1A',
#  'f56914cc-9cb0-4ea1-bfb9-00f47aba98ef.rna_seq.star_gene_counts.tsv.gz': 'hT25',
#  '4584bfa8-d55e-4bdc-a045-5b036c653a2a.FPKM.txt.gz': 'hM1F',
#  'b4d9e72d-329f-42e3-bf0b-0a6d588ddd0d.rna_seq.star_gene_counts.tsv.gz': 'hT103',
#  '11c215d3-3a8d-43e5-8227-f8e993e1e021.htseq_counts.txt.gz': 'hT25',
#  '018e080c-09c4-4911-9025-b5a2384ed71b.FPKM.txt.gz': 'hT98',
#  '1c75df78-5aca-4280-a22b-044670ba86ab.FPKM.txt.gz': 'hF23',
#  '8c71ff95-b3fe-4aa1-a1c8-ffe372c373a9.rna_seq.star_gene_counts.tsv.gz': 'hM19A',
#  'c5b00790-f1c8-46ee-bbdc-48fe1cab3e24.FPKM-UQ.txt.gz': 'hF32',
#  '495e2311-9c39-4a39-b01a-9353a08cb64d.rna_seq.star_gene_counts.tsv.gz': 'hT82',
#  'd8ab768a-388e-4dfe-afad-88d83c2329c4.htseq_counts.txt.gz': 'hT64',
#  'b850c213-ce46-4095-80a7-e38d7de12e08.FPKM.txt.gz': 'hT134',
#  '1efaf04d-28f9-4429-85eb-a786adee5500.htseq_counts.txt.gz': 'hT30',
#  'd8ab768a-388e-4dfe-afad-88d83c2329c4.FPKM.txt.gz': 'hT64',
#  '2205a0d2-bf0a-40f0-bf36-a96a8816325a.rna_seq.star_gene_counts.tsv.gz': 'hM1F',
#  '719f7392-0c7b-4529-99c3-b3db6c42b382.htseq_counts.txt.gz': 'hT81',
#  'a6ddcc84-8e4d-4c68-885c-2d51168eec97.FPKM.txt.gz': 'hT91',
#  '97512c95-1685-46a9-88db-071766889490.FPKM.txt.gz': 'hN31',
#  '30471596-3380-456a-8e55-2925b108e017.FPKM.txt.gz': 'hT85',
#  '9c110cd2-aca9-4fa4-8035-193554239aac.FPKM.txt.gz': 'hT106',
#  '6b2583f1-bbea-4020-ad73-8a59589b8cc3.FPKM.txt.gz': 'hF24',
#  'c4e77090-783a-4779-9673-c3c6f94f75e6.rna_seq.star_gene_counts.tsv.gz': 'hT64',
#  'ab82d4af-1327-4e2b-81e6-06ba12ee9e80.FPKM.txt.gz': 'hT60',
#  '425fe9f4-851a-435c-84ab-bafbb5c55022.htseq_counts.txt.gz': 'hT101',
#  'dd3f3d1f-12b8-4cc7-9f4c-105faef04a51.FPKM.txt.gz': 'hN30',
#  'ab82d4af-1327-4e2b-81e6-06ba12ee9e80.htseq_counts.txt.gz': 'hT60',
#  'fc29320e-ef34-49e4-97a8-642487dcc95a.FPKM-UQ.txt.gz': 'hT1'}

# %%
file_name_organid_save_path = 'data/organoid_pancreas/file_name_to_organoid_mapping.tsv'
save_filenames = []
save_organoids = []
for key in file_name_organid_dict:
    save_filenames.append(key)
    save_organoids.append(file_name_organid_dict[key])
pd.DataFrame({'filename':save_filenames,
              'organoid':save_organoids}).to_csv(file_name_organid_save_path,index=None,sep='\t')

# %%
drug_list = list(pancreas_drug_data_chemo.keys())

# %%
pancreas_drug_data_targeted = pd.read_excel('data/organoid_pancreas/S4_199398_2_supp_4775187_p95dln.xlsx',
                                  sheet_name = 2, header = 1)
print(pancreas_drug_data_targeted.shape)
pancreas_drug_data_targeted.head()
# Out:
# (66, 22)
#   Sample ID  Selumetinib  Afatinib  Bortezomib  Lapatinib  Sunitinib  \
# 0       hF2        0.728     0.772       0.250      0.750      0.740
# 1      hF23        0.692     0.548       0.232      0.762      0.814
# 2      hF24        0.758     0.632       0.238      0.862      0.916
# 3      hF27        0.816     0.828       0.274      0.816      0.780
# 4      hF28        0.700     0.668       0.236      0.842      0.844
#
#    Olaparib  Nutlin-3  MK-2206  KU-55933  ...  Ruxolitinib  SB5225334  \
# 0     0.716     0.800    0.756     0.812  ...        0.860      0.786
# 1     0.856     0.928    0.752     0.876  ...        0.848      0.748
# 2     0.854     0.910    0.780     0.842  ...        0.900      0.838
# 3     0.854     0.872    0.798     0.786  ...        0.862      0.828
# 4     0.838     0.856    0.768     0.866  ...        0.886      0.668
#
#    SGI-1776  OSI-420  TPCA-1  LY2874455  SF1670  K-ras(G12C) Inhibitor 9  \
# 0     0.788    0.806   0.784      0.654   0.734                    0.824
# 1     0.844    0.700   0.764      0.630   0.776                    0.850
# 2     0.862    0.798   0.838      0.678   0.854                    0.830
# 3     0.854    0.794   0.740      0.722   0.696                    0.818
# 4     0.794    0.838   0.824      0.570   0.766                    0.826
#
#    WIKI4  Disulfuram
# 0  0.698       0.538
# 1  0.838       0.516
# 2  0.858       0.578
# 3  0.798       0.572
# 4  0.818       0.470
#
# [5 rows x 22 columns]

# %%
drug_list += list(pancreas_drug_data_targeted.keys())

# %%
pancreas_drug_data_targeted_for_chem_refractory = pd.read_excel('data/organoid_pancreas/S4_199398_2_supp_4775187_p95dln.xlsx',
                                  sheet_name = 3, header = 1)
print(pancreas_drug_data_targeted_for_chem_refractory.shape)
pancreas_drug_data_targeted_for_chem_refractory.head()
# Out:
# (22, 29)
#   Sample ID  Basal-like?  Gemcitabine  Paclitaxel     SN-38      5-FU  \
# 0      hF27          NaN     0.677162    0.636766  0.567865  0.838669
# 1      hF28          NaN     0.685010    0.662779  0.651442  0.861745
# 2      hF45          NaN     0.653679    0.680984  0.715255  0.855193
# 3      hF70          NaN     0.917493    0.759485  0.880286  0.971617
# 4      hF77          NaN     0.743855    0.596951  0.658731  0.764028
#
#    Oxaliplatin  Selumetinib  Afatinib  Bortezomib  ...  SB5225334  SGI-1776  \
# 0     0.852603        0.816     0.828       0.274  ...      0.828     0.854
# 1     0.829213        0.700     0.668       0.236  ...      0.668     0.794
# 2     0.918398        0.814     0.698       0.256  ...      0.842     0.770
# 3     0.981540        0.802     0.844       0.274  ...      0.768     0.798
# 4     0.893167        0.786     0.722       0.264  ...      0.666     0.768
#
#    OSI-420  TPCA-1  LY2874455  SF1670  K-ras(G12C) Inhibitor 9  WIKI4  \
# 0    0.794   0.740      0.722   0.696                    0.818  0.798
# 1    0.838   0.824      0.570   0.766                    0.826  0.818
# 2    0.828   0.812      0.698   0.794                    0.792  0.846
# 3    0.826   0.882      0.764   0.798                    0.832  0.882
# 4    0.824   0.840      0.662   0.894                    0.816  0.746
#
#    Disulfuram  Alternative?
# 0       0.572           YES
# 1       0.470           YES
# 2       0.554            NO
# 3       0.564           YES
# 4       0.534           YES
#
# [5 rows x 29 columns]

# %%
drug_list += list(pancreas_drug_data_targeted_for_chem_refractory.keys())

# %%
print(list(set(drug_list)))
# Out:
# ['Insensitive', 'Paclitaxel', 'Bortezomib', 'WIKI4', 'Disulfuram', 'SF1670', 'Selumetinib', 'Sunitinib', 'Everolimus', 'Sample ID', 'Lapatinib', 'Nutlin-3', 'LY2874455', 'TPCA-1', 'Gemcitabine', 'Afatinib', 'Basal-like?', '5-FU', 'MK-2206', 'Olaparib', 'Ruxolitinib', 'OSI-420', 'K-ras(G12C) Inhibitor 9', 'KU-55933', 'SB5225334', 'SGI-1776', 'Alternative?', 'Oxaliplatin', 'Celecoxib', 'SN-38']

# %% [markdown]
# ### Extract inchi, inchi-key, smiles for compounds

# %%
unique_compounds = list(np.unique(drug_list))
use_fields = ['inchi','inchikey','canonical_smiles']
save_path = 'data/organoid_pancreas/pancreas_inhibitor_inchi_smiles.csv'
flag_redo = False
if not os.path.exists(save_path) or flag_redo:
    compound_pancreas_dict = {'inhibitor':[]}
    for i in tqdm(np.arange(len(unique_compounds))):
        cur_compound = unique_compounds[i]
        tmp_dict = utils.get_prop_dict_for_compound(cur_compound)
        for field in use_fields:
            if field not in compound_pancreas_dict:
                compound_pancreas_dict[field] = []
            try:
                cur_val = tmp_dict[field]
                compound_pancreas_dict[field].append(cur_val)
            except:
                compound_pancreas_dict[field].append(np.nan)
        compound_pancreas_dict['inhibitor'].append(cur_compound)
    pd.DataFrame(compound_pancreas_dict).to_csv(save_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
pancreas_smiles_data_path = 'data/organoid_pancreas/pancreas_inhibitor_inchi_smiles.csv'
pancreas_smiles_data = pd.read_csv(pancreas_smiles_data_path)
not_nan_instances = np.sum(np.array(pancreas_smiles_data['canonical_smiles'],dtype=np.str) != 'nan')
print('data for ' + str(not_nan_instances) + ' compounds [of ' +\
      str(pancreas_smiles_data.shape[0]) + ']')
pancreas_smiles_data.head()
# Out:
# data for 25 compounds [of 30]
#    Unnamed: 0     inhibitor  \
# 0           0          5-FU
# 1           1      Afatinib
# 2           2  Alternative?
# 3           3   Basal-like?
# 4           4    Bortezomib
#
#                                                inchi  \
# 0  InChI=1S/C4H3FN2O2/c5-2-1-6-4(9)7-3(2)8/h1H,(H...
# 1  InChI=1S/C24H25ClFN5O3/c1-31(2)8-3-4-23(32)30-...
# 2                                                NaN
# 3                                                NaN
# 4  InChI=1S/C19H25BN4O4/c1-13(2)10-17(20(27)28)24...
#
#                       inchikey  \
# 0  GHASVSINZRGABV-UHFFFAOYSA-N
# 1  ULXXDDBFHOBEHA-CWDCEQMOSA-N
# 2                          NaN
# 3                          NaN
# 4  GXJABQQUPOEUTA-RDJZCZTQSA-N
#
#                                     canonical_smiles
# 0                               C1=C(C(=O)NC(=O)N1)F
# 1  CN(C)CC=CC(=O)NC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC(...
# 2                                                NaN
# 3                                                NaN
# 4  B(C(CC(C)C)NC(=O)C(CC1=CC=CC=C1)NC(=O)C2=NC=CN...

# %%
use_drugs = []
all_drugs = list(pancreas_smiles_data['inhibitor'])
all_inchis = list(pancreas_smiles_data['inchi'])
for i in range(len(all_inchis)):
    if str(all_inchis[i]) != 'nan':
        use_drugs.append(all_drugs[i])
print('number of used drugs: ' + str(len(use_drugs)))
# Out:
# number of used drugs: 25

# %% [markdown]
# ### Create label file for data points with gene data

# %%
pancreas_drug_data_chemo.head()
# Out:
#   Sample ID  Gemcitabine  Paclitaxel     SN-38      5-FU  Oxaliplatin  \
# 0       hF2     0.554358    0.712962  0.499950  0.782922     0.887246
# 1      hF23     0.523995    0.486711  0.547860  0.781999     0.820843
# 2      hF24     0.609942    0.742389  0.549167  0.671272     0.809528
# 3      hF27     0.677162    0.636766  0.567865  0.838669     0.852603
# 4      hF28     0.685010    0.662779  0.651442  0.861745     0.829213
#
#   Insensitive
# 0         NaN
# 1         NaN
# 2         NaN
# 3         YES
# 4         YES

# %%
# merge the date using the key
gt_data = pancreas_drug_data_targeted_for_chem_refractory
gt_data = gt_data[['Sample ID'] + use_drugs]
gt_data.head()
# Out:
#   Sample ID      5-FU  Afatinib  Bortezomib  Celecoxib  Disulfuram  \
# 0      hF27  0.838669     0.828       0.274      0.798       0.572
# 1      hF28  0.861745     0.668       0.236      0.890       0.470
# 2      hF45  0.855193     0.698       0.256      0.860       0.554
# 3      hF70  0.971617     0.844       0.274      0.746       0.564
# 4      hF77  0.764028     0.722       0.264      0.840       0.534
#
#    Everolimus  Gemcitabine  K-ras(G12C) Inhibitor 9  KU-55933  ...  \
# 0       0.764     0.677162                    0.818     0.786  ...
# 1       0.750     0.685010                    0.826     0.866  ...
# 2       0.864     0.653679                    0.792     0.872  ...
# 3       0.724     0.917493                    0.832     0.830  ...
# 4       0.894     0.743855                    0.816     0.826  ...
#
#    Oxaliplatin  Paclitaxel  Ruxolitinib  SF1670  SGI-1776     SN-38  \
# 0     0.852603    0.636766        0.862   0.696     0.854  0.567865
# 1     0.829213    0.662779        0.886   0.766     0.794  0.651442
# 2     0.918398    0.680984        0.820   0.794     0.770  0.715255
# 3     0.981540    0.759485        0.888   0.798     0.798  0.880286
# 4     0.893167    0.596951        0.900   0.894     0.768  0.658731
#
#    Selumetinib  Sunitinib  TPCA-1  WIKI4
# 0        0.816      0.780   0.740  0.798
# 1        0.700      0.844   0.824  0.818
# 2        0.814      0.800   0.812  0.846
# 3        0.802      0.804   0.882  0.882
# 4        0.786      0.858   0.840  0.746
#
# [5 rows x 26 columns]

# %%
pancreas_value_save_path = 'data/organoid_pancreas/organoid_value.tsv'
organoids    = []
inhibitor = []
value     = []

data_dfs = [pancreas_drug_data_chemo,
            pancreas_drug_data_targeted,
            pancreas_drug_data_targeted_for_chem_refractory]
# used to store used combinations
used_combos = set()
for gt_data in data_dfs:
    organs = list(gt_data['Sample ID'])
    drugs = list(gt_data.columns[1:])
    values = np.array(gt_data.values[:,1:])
    print(values.shape)
    for i in range(len(organs)):
        cur_pat = organs[i]
        for j in range(len(drugs)):
            cur_drug = drugs[j]
            if cur_drug in use_drugs:
                cur_val = values[i,j]
                if np.isnan(cur_val):
                    continue
                cur_combo = cur_pat + '_' + cur_drug
                if cur_combo in used_combos:
                    continue
                used_combos.add(cur_combo)
                organoids.append(cur_pat)
                inhibitor.append(cur_drug)
                value.append(cur_val)
# Out:
# (66, 6)
# (66, 21)
# (22, 28)

# %%
print('number of organoids: ' + str(len(organoids)))
print('number of inhibitor: ' + str(len(inhibitor)))
print('number of value: ' + str(len(value)))
# Out:
# number of organoids: 1645
# number of inhibitor: 1645
# number of value: 1645

# %%
pancread_value_data = pd.DataFrame({'organoid':organoids,
                                'inhibitor':inhibitor,
                                'value':value})
pancread_value_data.to_csv(pancreas_value_save_path,sep='\t',index=None)

# %%
fpkm_path = 'data/organoid_pancreas/pancreas_organoid_fileids_fpkm.tsv'
fpkm_data = pd.read_csv(fpkm_path,sep='\t')
print(fpkm_data.shape)
fpkm_data.head()
# Out:
# (55, 8)
#   Access                                         File Name  Cases  \
# 0   open  9d26edab-7937-423c-8b5a-ac333211a29b.FPKM.txt.gz      1
# 1   open  955f9541-b394-4b28-90de-9101d24f72ad.FPKM.txt.gz      1
# 2   open  f888eea4-4fda-4f9f-a8cb-66e8219ce268.FPKM.txt.gz      1
# 3   open  d4f8538e-93d1-40ba-9c89-ad59ab96c1f7.FPKM.txt.gz      1
# 4   open  dec5e5a1-09c1-404c-8f50-ff351412dc31.FPKM.txt.gz      1
#
#                Project            Data Category Data Format  File Size  \
# 0  ORGANOID-PANCREATIC  Transcriptome Profiling         TXT  303.81 KB
# 1  ORGANOID-PANCREATIC  Transcriptome Profiling         TXT  306.34 KB
# 2  ORGANOID-PANCREATIC  Transcriptome Profiling         TXT   301.9 KB
# 3  ORGANOID-PANCREATIC  Transcriptome Profiling         TXT   304.1 KB
# 4  ORGANOID-PANCREATIC  Transcriptome Profiling         TXT  310.21 KB
#
#    Annotations
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
fpkm_data = pd.read_csv('data/organoid_pancreas/organoid_pancreas_fpkm.txt',sep='\t')
fpkm_data
# Out:
#                      id_0  11c215d3-3a8d-43e5-8227-f8e993e1e021.FPKM.txt  \
# 0      ENSG00000000003.13                                         9.0100
# 1       ENSG00000000005.5                                         0.0000
# 2      ENSG00000000419.11                                        48.2772
# 3      ENSG00000000457.12                                         4.2398
# 4      ENSG00000000460.15                                         3.5345
# ...                   ...                                            ...
# 60478   ENSGR0000275287.3                                         0.0000
# 60479   ENSGR0000276543.3                                         0.0000
# 60480   ENSGR0000277120.3                                         0.0000
# 60481   ENSGR0000280767.1                                         0.0000
# 60482   ENSGR0000281849.1                                         0.0000
#
#        9d26edab-7937-423c-8b5a-ac333211a29b.FPKM.txt  \
# 0                                             5.6222
# 1                                             0.0000
# 2                                            41.1670
# 3                                             3.3293
# 4                                             3.5172
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        6b2583f1-bbea-4020-ad73-8a59589b8cc3.FPKM.txt  \
# 0                                             5.8812
# 1                                             0.0000
# 2                                            61.5613
# 3                                             2.8488
# 4                                             2.5072
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        044f8701-5e9f-4300-beb2-41fef8096685.FPKM.txt  \
# 0                                            12.9486
# 1                                             0.0000
# 2                                            81.6943
# 3                                             5.2604
# 4                                             7.0305
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        30520ecd-c6bd-4039-9b1a-d3f999235598.FPKM.txt  \
# 0                                            16.2632
# 1                                             0.0304
# 2                                            36.3870
# 3                                             2.5943
# 4                                             0.8210
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        97512c95-1685-46a9-88db-071766889490.FPKM.txt  \
# 0                                            15.9627
# 1                                             0.0000
# 2                                            45.3314
# 3                                             3.8542
# 4                                             2.7092
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        8a84b3e2-92a0-4c2b-986b-0efa8a22a8f3.FPKM.txt  \
# 0                                            15.2014
# 1                                             0.0000
# 2                                            74.0640
# 3                                             2.8813
# 4                                             4.8934
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        dec5e5a1-09c1-404c-8f50-ff351412dc31.FPKM.txt  \
# 0                                            14.3398
# 1                                             0.0000
# 2                                            90.4289
# 3                                             5.0461
# 4                                             6.4371
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        30471596-3380-456a-8e55-2925b108e017.FPKM.txt  ...  \
# 0                                             9.7621  ...
# 1                                             0.0149  ...
# 2                                            39.7451  ...
# 3                                             3.5407  ...
# 4                                             1.7642  ...
# ...                                              ...  ...
# 60478                                         0.0000  ...
# 60479                                         0.0000  ...
# 60480                                         0.0000  ...
# 60481                                         0.0000  ...
# 60482                                         0.0000  ...
#
#        d7c7d4b8-19a5-4926-b215-067bd1d16c5a.FPKM.txt  \
# 0                                             7.5498
# 1                                             0.0136
# 2                                            50.8754
# 3                                             4.9141
# 4                                             4.0045
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        80b9fcf4-185c-4e52-bcff-8ab52ab4bfa5.FPKM.txt  \
# 0                                            14.5059
# 1                                             0.0000
# 2                                            37.8825
# 3                                             2.6460
# 4                                             2.0781
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        33aea564-8086-4b2d-a28d-eccc379ecfa6.FPKM.txt  \
# 0                                             9.5317
# 1                                             0.0000
# 2                                            61.9678
# 3                                             4.3635
# 4                                             5.6139
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        8236bc9d-2156-4991-a5eb-223e02229b3a.FPKM.txt  \
# 0                                            18.7515
# 1                                             0.0000
# 2                                            85.2760
# 3                                             3.1361
# 4                                             5.4499
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        d4f8538e-93d1-40ba-9c89-ad59ab96c1f7.FPKM.txt  \
# 0                                             9.0659
# 1                                             0.0000
# 2                                            64.1764
# 3                                             2.7565
# 4                                             2.6231
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        719f7392-0c7b-4529-99c3-b3db6c42b382.FPKM.txt  \
# 0                                             5.8760
# 1                                             0.0000
# 2                                            49.1493
# 3                                             3.4693
# 4                                             3.2286
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        dd3f3d1f-12b8-4cc7-9f4c-105faef04a51.FPKM.txt  \
# 0                                            10.0711
# 1                                             0.0000
# 2                                            38.6678
# 3                                             3.8800
# 4                                             1.7451
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        38b05dca-6d3f-4999-aded-0870bfd8f7e7.FPKM.txt  \
# 0                                            15.5382
# 1                                             0.0146
# 2                                            40.0392
# 3                                             2.2515
# 4                                             1.2433
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        7a33674a-4f33-452b-9ac5-cf692bd50229.FPKM.txt  \
# 0                                             8.1557
# 1                                             0.0000
# 2                                            64.8625
# 3                                             5.8210
# 4                                             2.2674
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
#        fc29320e-ef34-49e4-97a8-642487dcc95a.FPKM.txt
# 0                                             6.9453
# 1                                             0.0000
# 2                                            77.9880
# 3                                             3.3545
# 4                                             5.2872
# ...                                              ...
# 60478                                         0.0000
# 60479                                         0.0000
# 60480                                         0.0000
# 60481                                         0.0000
# 60482                                         0.0000
#
# [60483 rows x 56 columns]

# %%
import mygene as mygene
mg = mygene.MyGeneInfo()

# %%
from tqdm.notebook import tqdm
genes = list(fpkm_data['id_0'])
names = []
symbols = []
for i in tqdm(np.arange(len(genes))):
    cur_gene = genes[i]
    try:
        cur_gene_dict = mg.getgene(cur_gene.split('.')[0],fields='name,symbol')
        cur_symbol = cur_gene_dict['symbol']
        cur_name = cur_gene_dict['name']
        names.append(cur_name)
        symbols.append(cur_symbol)
    except:
        names.append(np.nan)
        symbols.append(np.nan)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60483.0), HTML(value='')))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
save_path = 'data/organoid_pancreas/gene_name_symbol_mapping.tsv'
save_data = pd.DataFrame({'gene':genes[0:len(names)],
                          'symbol':symbols,
                          'name':names}).to_csv(save_path,index=None,sep='\t')

# %% [markdown]
# ## Xenografts data

# %%
xenografts_data = pd.read_csv('data/lung_cancer_xenografts/sample_info.txt',sep='\t')
print(xenografts_data.shape)
xenografts_data.head()
# Out:
# (53, 31)
#   sample_name                                         file_name   group  \
# 0          3T  3T_MRS447_ACTTGA_L002_bwa_hg19_unique_sorted.bam  Tumour
# 1          4T  4T_MRS449_GGCTAC_L002_bwa_hg19_unique_sorted.bam  Tumour
# 2          5T  5T_MRS403_ACTTGA_L001_bwa_hg19_unique_sorted.bam  Tumour
# 3          6T  6T_MRS403_GGCTAC_L001_bwa_hg19_unique_sorted.bam  Tumour
# 4          7T  7T_MRS475_ACTTGA_L001_bwa_hg19_unique_sorted.bam  Tumour
#
#   patient  pat_id                                              input  \
# 0    Pat3  7166.0                                                NaN
# 1    Pat4  7177.0  mpimg_L5312-1_Pat4-7177-tumor_CGATGT_L008_bwa_...
# 2    Pat5  7187.0  mpimg_L5316-1_Pat5-7187-tumor_GCCAAT_L008_bwa_...
# 3    Pat6  7198.0  mpimg_L5318-1_Pat6-7198-tumor_ACTTGA_L008_bwa_...
# 4    Pat7  7298.0                                                NaN
#
#                                         9mb_filename histology   age sex  ...  \
# 0  /project/43/SOLiD/PREDICT/bioscope/7166LuCa3TU...       LCC  70.0   M  ...
# 1  /project/43/SOLiD/PREDICT/bioscope/7177LuCa4TU...       SQC  42.0   M  ...
# 2  /project/43/SOLiD/PREDICT/bioscope/7187LuCa5TU...       PLC  38.0   F  ...
# 3  /project/43/SOLiD/PREDICT/bioscope/7198LuCa6TU...       ADC  60.0   F  ...
# 4  /project/43/SOLiD/PREDICT/bioscope/7298LuCa7TU...       SQC  73.0   M  ...
#
#    stage2  stage3  stage4  stage5                        treatment  etp_chs  \
# 0     pN2     cM0      G3      R0                               No       ++
# 1    ypN2     cM0      G3      R0  5 cycles carboplatin/paclitaxel        -
# 2     pN0     cM0      G3      R0                               No        -
# 3     pN0     cM0      G3      R0                               No        -
# 4     pN2     cM0      G3      R1                               No        +
#
#    carpl_chs  gem_chs  paltx_chs erlo_chs
# 0         ++        +          -        -
# 1         ++      +++          -       ++
# 2         ++      +++          -        -
# 3          +        +          +        -
# 4          +     ++++          -      NaN
#
# [5 rows x 31 columns]

# %%
np.unique(xenografts_data['pat_id'])
# Out:
# array([7166., 7177., 7187., 7198., 7298., 7336., 7343., 7406., 7414.,
#        7433., 7462., 7466., 7506., 7530., 7558., 7612., 7668., 7700.,
#        7747., 7766., 7860., 7913., 9643.,   nan,   nan,   nan,   nan])

# %%
gene_data_path = 'data/lung_cancer_xenografts/normalized_expression.remoatFiltered.geneLevel.txt'
gene_data = pd.read_csv(gene_data_path,sep='\t')
gene_data.head()
# Out:
#     HGNC  Entrez  7177.N_9347469042_C.intensity  \
# 0    7A5  346389                     132.667209
# 1   A1BG       1                     130.056266
# 2   A1CF   29974                     127.681633
# 3  A26C3   23784                     131.084200
# 4  A2BP1   54715                     127.507817
#
#    7177.N_9347469042_C.detectionPvalue  7177.X_9347469042_D.intensity  \
# 0                             0.287013                     129.242318
# 1                             0.409091                     127.412775
# 2                             0.555844                     129.255691
# 3                             0.475758                     129.942883
# 4                             0.565584                     129.514538
#
#    7177.X_9347469042_D.detectionPvalue  7187.N_9347469042_E.intensity  \
# 0                             0.474026                     140.573763
# 1                             0.601299                     137.783727
# 2                             0.481818                     128.692008
# 3                             0.435065                     126.868342
# 4                             0.459091                     128.363275
#
#    7187.N_9347469042_E.detectionPvalue  7187.X_9347469042_F.intensity  \
# 0                             0.051948                     143.664824
# 1                             0.088312                     129.688301
# 2                             0.478355                     130.113771
# 3                             0.607792                     122.097278
# 4                             0.509416                     127.956717
#
#    7187.X_9347469042_F.detectionPvalue  ...  10711.X_9481417016_H.intensity  \
# 0                             0.025974  ...                      146.627596
# 1                             0.448052  ...                      133.145629
# 2                             0.444156  ...                      133.793170
# 3                             0.867532  ...                      132.033661
# 4                             0.566558  ...                      126.420781
#
#    10711.X_9481417016_H.detectionPvalue  10684.X_9481417016_I.intensity  \
# 0                              0.000427                      126.215411
# 1                              0.302001                      129.843623
# 2                              0.275176                      132.845540
# 3                              0.361921                      128.014570
# 4                              0.775223                      131.994498
#
#    10684.X_9481417016_I.detectionPvalue  10855.X_9481417016_J.intensity  \
# 0                              0.831135                      125.411244
# 1                              0.497602                      130.534919
# 2                              0.373295                      123.976642
# 3                              0.662429                      129.431746
# 4                              0.372284                      124.248804
#
#    10855.X_9481417016_J.detectionPvalue  10872.X_9481417016_K.intensity  \
# 0                              0.880294                      154.101187
# 1                              0.441108                      131.158108
# 2                              0.980969                      129.734518
# 3                              0.452032                      131.062658
# 4                              0.950678                      133.418111
#
#    10872.X_9481417016_K.detectionPvalue  11187.X_9481417016_L.intensity  \
# 0                              0.000496                      134.972453
# 1                              0.419154                      125.174744
# 2                              0.567463                      133.081947
# 3                              0.501986                      133.528947
# 4                              0.333986                      127.600072
#
#    11187.X_9481417016_L.detectionPvalue
# 0                              0.180760
# 1                              0.937832
# 2                              0.433837
# 3                              0.446474
# 4                              0.616958
#
# [5 rows x 118 columns]

# %%
patient_column = ['pat_id']
drug_names = ['Carboplatin','Gemcitabin','Etoposid','Paclitaxel','Erlotinib','Cetuximab','Bevacizumab']
save_drug_response_path = 'data/lung_cancer_xenografts/drug_response.tsv'
save_data = xenografts_data[patient_column + drug_names]
save_data.head()
save_data.to_csv(save_drug_response_path,sep='\t',index=None)

# %%
drug_list = list(drug_names)

# %% [markdown]
# #### save data in format pat_id, drug, value

# %%
drugs    = list(save_data.columns)[1:]
patients = list(np.array(save_data['pat_id']))
values   = np.array(save_data.values[:,1:])
print(len(drugs))
print(len(patients))
print(values.shape)
# Out:
# 7
# 53
# (53, 7)

# %%
pat_id    = []
inhibitor = []
value     = []
for i in range(len(patients)):
    cur_pat = patients[i]
    for j in range(len(drugs)):
        cur_drug = drugs[j]
        cur_val = values[i,j]
        if np.isnan(cur_pat):
            continue
        pat_id.append(cur_pat)
        inhibitor.append(cur_drug)
        value.append(cur_val)
xeno_value_data = pd.DataFrame({'pat_id':pat_id,
                                'inhibitor':inhibitor,
                                'value':value})
save_xenografts_response_path = 'data/lung_cancer_xenografts/xenografts_value.tsv'
xeno_value_data.to_csv(save_xenografts_response_path,sep='\t',index=None)

# %% [markdown]
# ### Extract inchi, inchi-key, smiles for compounds

# %%
unique_compounds = list(np.unique(drug_list))
use_fields = ['inchi','inchikey','canonical_smiles']
save_path = 'data/lung_cancer_xenografts/xenografts_inhibitor_inchi_smiles.csv'
flag_redo = False
if not os.path.exists(save_path) or flag_redo:
    compound_xenografts_dict = {'inhibitor':[]}
    for i in tqdm(np.arange(len(unique_compounds))):
        cur_compound = unique_compounds[i]
        tmp_dict = utils.get_prop_dict_for_compound(cur_compound)
        for field in use_fields:
            if field not in compound_xenografts_dict:
                compound_xenografts_dict[field] = []
            try:
                cur_val = tmp_dict[field]
                compound_xenografts_dict[field].append(cur_val)
            except:
                compound_xenografts_dict[field].append(np.nan)
        compound_xenografts_dict['inhibitor'].append(cur_compound)
    pd.DataFrame(compound_xenografts_dict).to_csv(save_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7.0), HTML(value='')))

# %%
xenografts_smiles_data_path = 'data/lung_cancer_xenografts/xenografts_inhibitor_inchi_smiles.csv'
xenografts_smiles_data = pd.read_csv(xenografts_smiles_data_path)
not_nan_instances = np.sum(np.array(xenografts_smiles_data['canonical_smiles'],dtype=np.str) != 'nan')
print('data for ' + str(not_nan_instances) + ' compounds [of ' +\
      str(xenografts_smiles_data.shape[0]) + ']')
xenografts_smiles_data.head()
# Out:
# data for 3 compounds [of 7]
#    Unnamed: 0    inhibitor                                              inchi  \
# 0           0  Bevacizumab                                                NaN
# 1           1  Carboplatin  InChI=1S/C6H8O4.2H2N.Pt/c7-4(8)6(5(9)10)2-1-3-...
# 2           2    Cetuximab                                                NaN
# 3           3    Erlotinib  InChI=1S/C22H23N3O4/c1-4-16-6-5-7-17(12-16)25-...
# 4           4     Etoposid                                                NaN
#
#                       inchikey  \
# 0                          NaN
# 1  VSRXQHXAPYXROS-UHFFFAOYSA-N
# 2                          NaN
# 3  AAKJLRGGTJKAMG-UHFFFAOYSA-N
# 4                          NaN
#
#                                     canonical_smiles
# 0                                                NaN
# 1        C1CC(C1)(C(=O)O)C(=O)O.[NH2-].[NH2-].[Pt+2]
# 2                                                NaN
# 3  COCCOC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC=CC(=C3)C#C...
# 4                                                NaN

# %% [markdown]
# ## CCLE data

# %%
ccle_cell_line_annotations = pd.read_csv('data/ccle/CCLE_sample_info_file_2012-10-18.txt',sep='\t')
print(ccle_cell_line_annotations.shape)
ccle_cell_line_annotations.head()
# Out:
# (1046, 13)
#                        CCLE name Cell line primary name Cell line aliases  \
# 0  1321N1_CENTRAL_NERVOUS_SYSTEM                 1321N1               NaN
# 1                      143B_BONE                   143B               NaN
# 2                 22RV1_PROSTATE                  22Rv1               NaN
# 3                2313287_STOMACH               23132/87               NaN
# 4           253JBV_URINARY_TRACT                253J-BV               NaN
#
#   Gender            Site Primary     Histology                Hist Subtype1  \
# 0      M  central_nervous_system        glioma                  astrocytoma
# 1      F                    bone  osteosarcoma                           NS
# 2      M                prostate     carcinoma                           NS
# 3      M                 stomach     carcinoma               adenocarcinoma
# 4      U           urinary_tract     carcinoma  transitional_cell_carcinoma
#
#                                                Notes Source  \
# 0  Identical lines: U-118 MG, U-138 MG and 1321N1...  ECACC
# 1  Identical lines: HTK-, HOS and 143B share high...   ATCC
# 2                                                NaN   ATCC
# 3                                                NaN   DSMZ
# 4  Identical lines: 253J and 253J-BV share high S...   KCLB
#
#                               Expression arrays  \
# 0   NIECE_p_NCLE_RNA3_HG-U133_Plus_2_B06_296024
# 1   MAKER_p_NCLE_RNA7_HG-U133_Plus_2_F09_454702
# 2   NIECE_p_NCLE_RNA3_HG-U133_Plus_2_F06_296120
# 3   WATCH_p_NCLE_RNA8_HG-U133_Plus_2_E11_474718
# 4  CRAZY_p_NCLE_RNA10_HG-U133_Plus_2_A05_569490
#
#                                           SNP arrays Oncomap  \
# 0  HONEY_p_NCLE_DNAAffy3_S_GenomeWideSNP_6_E09_29...     yes
# 1   BOWER_p_NCLE_DNAAffy8_GenomeWideSNP_6_D02_464552     yes
# 2      LIMPS_p_NCLE_DNA2N_GenomeWideSNP_6_C09_246674     yes
# 3   CHARY_p_NCLE_DNAAffy9_GenomeWideSNP_6_D06_490336     yes
# 4                                                NaN     yes
#
#   Hybrid Capture Sequencing
# 0                       NaN
# 1                       NaN
# 2                       yes
# 3                       yes
# 4                       yes

# %%
pharm_drug_data = pd.read_csv('data/ccle/CCLE_NP24.2009_Drug_data_2015.02.24.csv',sep=',')
print(pharm_drug_data.shape)
pharm_drug_data.head()
# Out:
# (11670, 13)
#              CCLE Cell Line Name Primary Cell Line Name Compound Target  \
# 0  1321N1_CENTRAL_NERVOUS_SYSTEM                 1321N1   AEW541  IGF1R
# 1                 22RV1_PROSTATE                  22Rv1   AEW541  IGF1R
# 2  42MGBA_CENTRAL_NERVOUS_SYSTEM               42-MG-BA   AEW541  IGF1R
# 3             5637_URINARY_TRACT                   5637   AEW541  IGF1R
# 4             639V_URINARY_TRACT                  639-V   AEW541  IGF1R
#
#                              Doses (uM)  \
# 0  .0025,.0080,.025,.080,.25,.80,2.53,8
# 1  .0025,.0080,.025,.080,.25,.80,2.53,8
# 2  .0025,.0080,.025,.080,.25,.80,2.53,8
# 3  .0025,.0080,.025,.080,.25,.80,2.53,8
# 4  .0025,.0080,.025,.080,.25,.80,2.53,8
#
#                   Activity Data (median)  \
# 0     8.67,11.0,2.16,.27,-10,-13,-26,-43
# 1      .94,12.5,-14,4.16,-25,-32,-52,-71
# 2  8.91,8.39,-3.5,12.4,-.55,-6.2,-48,-63
# 3   2.15,9.91,-3.5,.056,-2.1,-14,-30,-62
# 4     11.8,-7.3,-9.4,-15,-11,-21,-53,-50
#
#                                Activity SD  Num Data  FitType  EC50 (uM)  \
# 0   3.31,3.72,5.36,4.67,13.1,.18,2.42,7.51         8  Sigmoid   8.717774
# 1  1.95,13.3,6.98,21.8,16.0,18.8,4.84,7.93         8  Sigmoid   8.165164
# 2  13.7,7.70,11.1,6.43,24.0,9.57,9.57,10.4         8  Sigmoid   1.514508
# 3   4.05,9.75,12.7,4.36,11.0,10.0,24.6,.14         8  Sigmoid   8.006595
# 4    .95,5.67,11.1,.68,31.6,22.3,1.45,3.08         8  Sigmoid   0.931196
#
#    IC50 (uM)       Amax  ActArea
# 0   8.000000 -42.558014   0.7124
# 1   2.329924 -71.589340   1.6723
# 2   2.682130 -63.491371   1.1852
# 3   5.002314 -62.352776   0.9948
# 4   1.736181 -51.959808   1.5436

# %%
pat_id    = []
inhibitor = []
value     = []
patients  = list(pharm_drug_data['CCLE Cell Line Name'])
drugs     = list(pharm_drug_data['Compound'])
values    = list(pharm_drug_data['IC50 (uM)'])
for i in range(len(patients)):
    cur_pat = patients[i]
    cur_drug = drugs[i]
    cur_val = values[i]
    pat_id.append(cur_pat)
    inhibitor.append(cur_drug)
    value.append(cur_val)
ccle_value_data = pd.DataFrame({'pat_id':pat_id,
                                'inhibitor':inhibitor,
                                'value':value})
save_ccle_response_path = 'data/ccle/ccle_value.tsv'
ccle_value_data.to_csv(save_ccle_response_path,sep='\t',index=None)

# %% [markdown]
# ### Extract inchi, inchi-key, smiles for compounds

# %%
drug_list = list(pharm_drug_data['Compound'])
unique_compounds = list(np.unique(drug_list))
use_fields = ['inchi','inchikey','canonical_smiles']
save_path = 'data/ccle/ccle_inhibitor_inchi_smiles.csv'
flag_redo = False
if not os.path.exists(save_path) or flag_redo:
    compound_ccle_dict = {'inhibitor':[]}
    for i in tqdm(np.arange(len(unique_compounds))):
        cur_compound = unique_compounds[i]
        tmp_dict = utils.get_prop_dict_for_compound(cur_compound)
        for field in use_fields:
            if field not in compound_ccle_dict:
                compound_ccle_dict[field] = []
            try:
                cur_val = tmp_dict[field]
                compound_ccle_dict[field].append(cur_val)
            except:
                compound_ccle_dict[field].append(np.nan)
        compound_ccle_dict['inhibitor'].append(cur_compound)
    pd.DataFrame(compound_ccle_dict).to_csv(save_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %%
pd.DataFrame(compound_ccle_dict).head()
# Out:
#    inhibitor                                              inchi  \
# 0     17-AAG  InChI=1S/C31H43N3O8/c1-8-12-33-26-21-13-17(2)1...
# 1     AEW541  InChI=1S/C27H29N5O/c28-26-25-24(21-8-4-9-23(14...
# 2    AZD0530  InChI=1S/C27H32ClN5O5/c1-32-6-8-33(9-7-32)10-1...
# 3    AZD6244  InChI=1S/C17H15BrClFN4O3/c1-24-8-21-16-13(24)7...
# 4  Erlotinib  InChI=1S/C22H23N3O4/c1-4-16-6-5-7-17(12-16)25-...
#
#                       inchikey  \
# 0  AYUNIORJHRXIBJ-TXHRRWQRSA-N
# 1  AECDBHGVIIRMOI-UHFFFAOYSA-N
# 2  OUKYUETWWIPKQR-UHFFFAOYSA-N
# 3  CYOHGALHFOKKQC-UHFFFAOYSA-N
# 4  AAKJLRGGTJKAMG-UHFFFAOYSA-N
#
#                                     canonical_smiles
# 0  CC1CC(C(C(C=C(C(C(C=CC=C(C(=O)NC2=CC(=O)C(=C(C...
# 1  C1CN(C1)CC2CC(C2)N3C=C(C4=C(N=CN=C43)N)C5=CC(=...
# 2  CN1CCN(CC1)CCOC2=CC3=C(C(=C2)OC4CCOCC4)C(=NC=N...
# 3  CN1C=NC2=C1C=C(C(=C2F)NC3=C(C=C(C=C3)Br)Cl)C(=...
# 4  COCCOC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC=CC(=C3)C#C...

# %%
drug_profiling_data = pd.read_csv('data/ccle/CCLE_NP24.2009_profiling_2012.02.20.csv',sep=',')
print(drug_profiling_data.shape)
drug_profiling_data.head()
# Out:
# (24, 7)
#   Compound (code or generic name) Compound (brand name)   Target(s)  \
# 0                       Erlotinib               Tarceva        EGFR
# 1                       Lapatinib                Tykerb  EGFR, HER2
# 2                      PHA-665752                   NaN       c-MET
# 3                      PF-2341066            Crizotinib  c-MET, ALK
# 4                          TAE684                   NaN         ALK
#
#        Mechanism of action             Class  Highest Phase     Organization
# 0          EGFR  Inhibitor  Kinase inhibitor  Launched-2004        Genentech
# 1  EGFR and HER2 Inhibitor  Kinase inhibitor  Launched-2007  GlaxoSmithKline
# 2          c-MET Inhibitor  Kinase inhibitor    Preclinical          Pfizer
# 3  c-MET and ALK Inhibitor  Kinase inhibitor  Launched-2011          Pfizer
# 4            ALK Inhibitor  Kinase inhibitor    Preclinical         Novartis

# %%
rpkm_gene_data = pd.read_csv('data/ccle/CCLE_DepMap_18q3_RNAseq_RPKM_20180718.gct', sep='\t',skiprows=2)
print(rpkm_gene_data.shape)
rpkm_gene_data.head()
# Out:
# (56318, 1158)
#                 Name Description  22RV1_PROSTATE (ACH-000956)  \
# 0  ENSG00000223972.4     DDX11L1                      0.00000
# 1  ENSG00000227232.4      WASH7P                     12.63011
# 2  ENSG00000243485.2  MIR1302-11                      0.04289
# 3  ENSG00000237613.2     FAM138A                      0.00000
# 4  ENSG00000268020.2      OR4G4P                      0.00000
#
#    2313287_STOMACH (ACH-000948)  253JBV_URINARY_TRACT (ACH-000026)  \
# 0                       0.03755                            0.00000
# 1                      10.14155                            6.20657
# 2                       0.01037                            0.16955
# 3                       0.00869                            0.22423
# 4                       0.00000                            0.02886
#
#    253J_URINARY_TRACT (ACH-000011)  \
# 0                          0.06507
# 1                          6.55835
# 2                          0.23364
# 3                          0.16558
# 4                          0.03875
#
#    42MGBA_CENTRAL_NERVOUS_SYSTEM (ACH-000323)  \
# 0                                     0.00000
# 1                                     7.61752
# 2                                     0.08765
# 3                                     0.00000
# 4                                     0.00000
#
#    5637_URINARY_TRACT (ACH-000905)  59M_OVARY (ACH-000520)  \
# 0                          0.01378                 0.01463
# 1                          6.19356                 4.62277
# 2                          0.00000                 0.00808
# 3                          0.00637                 0.00000
# 4                          0.00000                 0.00000
#
#    639V_URINARY_TRACT (ACH-000973)  ...  UMUC16_URINARY_TRACT (ACH-001409)  \
# 0                          0.03085  ...                            0.00000
# 1                          6.00767  ...                            6.42321
# 2                          0.09373  ...                            0.12367
# 3                          0.01427  ...                            0.01554
# 4                          0.00000  ...                            0.00667
#
#    UMUC4_URINARY_TRACT (ACH-001410)  UMUC5_URINARY_TRACT (ACH-001411)  \
# 0                           0.02977                           0.02999
# 1                           8.17443                           7.75149
# 2                           0.19183                           0.10492
# 3                           0.00459                           0.01850
# 4                           0.01182                           0.01786
#
#    UMUC6_URINARY_TRACT (ACH-001414)  UMUC7_URINARY_TRACT (ACH-001415)  \
# 0                           0.03532                           0.03831
# 1                           9.97036                           8.17080
# 2                           0.18537                           0.07408
# 3                           0.04903                           0.01330
# 4                           0.01052                           0.01141
#
#    UMUC9_URINARY_TRACT (ACH-001416)  \
# 0                           0.03236
# 1                           8.70551
# 2                           0.07747
# 3                           0.00000
# 4                           0.00642
#
#    UPCISCC152_UPPER_AERODIGESTIVE_TRACT (ACH-001228)  \
# 0                                            0.00000
# 1                                           15.23348
# 2                                            0.07448
# 3                                            0.02674
# 4                                            0.00000
#
#    UW228_CENTRAL_NERVOUS_SYSTEM (ACH-001232)  \
# 0                                    0.03799
# 1                                    6.47732
# 2                                    0.01049
# 3                                    0.00879
# 4                                    0.00000
#
#    Y79_AUTONOMIC_GANGLIA (ACH-001295)  YAMATO_SOFT_TISSUE (ACH-001277)
# 0                             0.02907                          0.00000
# 1                             8.45568                         11.81688
# 2                             0.39607                          0.17586
# 3                             0.26449                          0.02266
# 4                             0.00000                          0.01459
#
# [5 rows x 1158 columns]

# %%
cols = rpkm_gene_data.columns
use_cols = []
for i in range(len(cols)):
    if '(ACH' in cols[i]:
        use_cols.append(cols[i].split('(ACH-')[0].strip())
    else:
        use_cols.append(cols[i])

# %%
rpkm_gene_data.columns = use_cols
rpkm_gene_data.head()
# Out:
#                 Name Description  22RV1_PROSTATE  2313287_STOMACH  \
# 0  ENSG00000223972.4     DDX11L1         0.00000          0.03755
# 1  ENSG00000227232.4      WASH7P        12.63011         10.14155
# 2  ENSG00000243485.2  MIR1302-11         0.04289          0.01037
# 3  ENSG00000237613.2     FAM138A         0.00000          0.00869
# 4  ENSG00000268020.2      OR4G4P         0.00000          0.00000
#
#    253JBV_URINARY_TRACT  253J_URINARY_TRACT  42MGBA_CENTRAL_NERVOUS_SYSTEM  \
# 0               0.00000             0.06507                        0.00000
# 1               6.20657             6.55835                        7.61752
# 2               0.16955             0.23364                        0.08765
# 3               0.22423             0.16558                        0.00000
# 4               0.02886             0.03875                        0.00000
#
#    5637_URINARY_TRACT  59M_OVARY  639V_URINARY_TRACT  ...  \
# 0             0.01378    0.01463             0.03085  ...
# 1             6.19356    4.62277             6.00767  ...
# 2             0.00000    0.00808             0.09373  ...
# 3             0.00637    0.00000             0.01427  ...
# 4             0.00000    0.00000             0.00000  ...
#
#    UMUC16_URINARY_TRACT  UMUC4_URINARY_TRACT  UMUC5_URINARY_TRACT  \
# 0               0.00000              0.02977              0.02999
# 1               6.42321              8.17443              7.75149
# 2               0.12367              0.19183              0.10492
# 3               0.01554              0.00459              0.01850
# 4               0.00667              0.01182              0.01786
#
#    UMUC6_URINARY_TRACT  UMUC7_URINARY_TRACT  UMUC9_URINARY_TRACT  \
# 0              0.03532              0.03831              0.03236
# 1              9.97036              8.17080              8.70551
# 2              0.18537              0.07408              0.07747
# 3              0.04903              0.01330              0.00000
# 4              0.01052              0.01141              0.00642
#
#    UPCISCC152_UPPER_AERODIGESTIVE_TRACT  UW228_CENTRAL_NERVOUS_SYSTEM  \
# 0                               0.00000                       0.03799
# 1                              15.23348                       6.47732
# 2                               0.07448                       0.01049
# 3                               0.02674                       0.00879
# 4                               0.00000                       0.00000
#
#    Y79_AUTONOMIC_GANGLIA  YAMATO_SOFT_TISSUE
# 0                0.02907             0.00000
# 1                8.45568            11.81688
# 2                0.39607             0.17586
# 3                0.26449             0.02266
# 4                0.00000             0.01459
#
# [5 rows x 1158 columns]

# %%
rpkm_gene_data.to_csv('data/ccle/rpkm_gene_data.csv',sep='\t',index=None)
