# %% [markdown]
# # Notebook to plot and print tables

# %%
# imports
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import os
import json
import scipy

#!pip install pycombat
import sys
from pycombat import Combat

import matplotlib.pyplot as plt
import utils as utils
import argparse
import socket
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GroupKFold
import tensorflow as tf
import models as models
import evaluation as evaluation
import traceback
import paccmann_model as paccmann_model
import joblib
import warnings
warnings.filterwarnings("ignore")

# %pylab inline
# %load_ext autoreload
# %autoreload 2

print(socket.gethostname())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ift-dgx

# %% [markdown]
# ## Precision Oncology

# %%
save_dir = 'results/'
save_prefix = ''
source = 'gdsc'
targets = ['ccle','pancreas','xenografts','beat_aml']
target_number_mapping = {'ccle':[0,10,50,100,500,1000,5000,10000],
                         'pancreas':[0,10,50,100,500,10000],
                         'beat_aml':[0,10,50,100,500,1000,5000,10000,20000],
                         'xenografts':[0,10,50,10000]}

flag_compare_pretrain_scratch = True
flag_normalize_descriptors = True
train_mode = 'precision_oncology'
use_netpop = 'ensemble'
save_fig_prefix = 'only_pretrain_'

investigate_list = ['pearson_lab']#'pearson_inhib',]#'pearson','pearson_inhib','spearman','spearman_inhib']
metric_mapping_dict = {'pearson':'Pearson correlation',
                      'pearson_inhib':'Per-inhibitor pearson correlation',
                      'spearman':'Spearman correlation',
                      'spearman_inhib':'Per-inhibitor spearman correlation',
                      'pearson_lab': 'Per-specimen pearson correlation'}

model_mapping_dict = {'nn_baseline_scratch' :'Conv NN [scratch]',
                      'nn_baseline_pretrain':'Conv NN [pre-train]',
                      'nn_paccmann_scratch' : 'PaccMann [scratch]',
                      'nn_paccmann_pretrain' :'PaccMann [pre-train]',
                      'rf':'Random Forest',
                      'tDNN_scratch': 'tDNN [scratch]',
                      'tDNN_pretrain': 'tDNN [pre-train]'}


model_names = ['nn_baseline_scratch', 'nn_baseline_pretrain', 
               'nn_paccmann_scratch', 'nn_paccmann_pretrain',
               'tDNN_scratch', 'tDNN_pretrain',
              # 'rf',
              ]

investigate_list_small = ['pearson_lab']#['pearson_inhib','pearson_lab']

# plot params
pval = 0.05 #p-value for ttest
decs = 3
invers_scale_list = [False]

for target in targets:
    use_samples_list = target_number_mapping[target]
    list_use_samples = []
    all_result_dicts = []
    for use_samples in use_samples_list:
        cur_load_path = save_dir +  save_prefix + source + '_' + target + '_' + str(use_samples) +\
                '_' + str(flag_normalize_descriptors) + '_' + str(train_mode) + '_' + str(use_netpop) + '.joblib'
        print('cur_load_path: ' + cur_load_path)
        if not os.path.exists(cur_load_path):
            print('does not exist')
            continue
        cur_tmp_dict = joblib.load(cur_load_path)
        all_result_dicts.append(cur_tmp_dict)
        list_use_samples.append(use_samples)
    
    print('source: ' + str(source))
    print('target: ' + str(target))
    result_table_dict = dict()
    keys = np.arange(len(all_result_dicts))
    for j in tqdm(np.arange(len(keys))):
        cur_key = list_use_samples[j]
        if cur_key not in result_table_dict:
            result_table_dict[cur_key] = dict()
        cur_num_train_results = all_result_dicts[j]
        model_keys = model_mapping_dict.keys()
        for model_key in model_keys:
            if model_key not in result_table_dict[cur_key]:
                result_table_dict[cur_key][model_key] = dict()
            if model_key in cur_num_train_results:
                cur_model_results = cur_num_train_results[model_key]
                min_max_scaler = None
                if 'min_max_scaler' in cur_num_train_results:
                    min_max_scaler = cur_num_train_results['min_max_scaler']
                tmp_res_dict = evaluation.get_metric_dict(cur_model_results['pred_complete'], cur_model_results['gt_complete'],
                                            cur_model_results['inhib_data_complete'],cur_model_results['lab_data_complete'],
                                            min_max_scaler, invers_scale_list = invers_scale_list,
                                            flag_calc_per_lab = True,
                                            flag_calc_per_inhib = False)

                tmp_res_keys = tmp_res_dict.keys()
                for key in tmp_res_keys:
                    result_table_dict[cur_key][model_key][key] = tmp_res_dict[key]
            

    print('################################################')
    print('#')
    print('# PRINT TABLE ONLY PEARSON')
    print('#')
    print('################################################')    

    for investigate in investigate_list_small:
        print('investigate: ' + str(investigate))
        num_trains = result_table_dict.keys()
        for num_train in num_trains:
            cur_str = ''#metric_mapping_dict[investigate]
            if num_train is None:
                display_number = 'all'
            else:
                display_number = str(num_train)
            cur_str += display_number #' & ' + display_number
            cur_results = result_table_dict[num_train]        
            result_lists = []
            result_means = []
            restult_std_errors = []
            result_strings = []
            for model in model_names:
                if model not in cur_results:
                    continue
                model_res = cur_results[model]
                if len(model_res) > 0:
                    cur_list = model_res[investigate + '_list']
                    result_lists.append(cur_list)
                    result_means.append(np.mean(cur_list))
                    restult_std_errors.append(np.std(cur_list) / np.sqrt(len(cur_list)))
                    result_string = str(np.round(np.mean(cur_list),decimals = decs)) +\
                                ' $\pm$ ' + str(np.round(np.std(cur_list) / np.sqrt(len(cur_list)),decimals = decs))
                    if 'pretrain' in model and model.replace('pretrain','scratch') in model_names:
                        pretrain_list = cur_list
                        try:
                            scratch_list = cur_results[model.replace('pretrain','scratch')][investigate + '_list']
                            if np.mean(pretrain_list) > np.mean(scratch_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                                # perform statistical test to compare pretrain with scratch version
                                stats,pvalue = scipy.stats.ttest_ind(pretrain_list,scratch_list)
                                
                                if pvalue < pval:
                                    result_string += '*'
                        except:
                            pass
                    if 'scratch' in model and model.replace('pretrain','scratch') in model_names:
                        scratch_list = cur_list
                        try:
                            pretrain_list = cur_results[model.replace('scratch','pretrain')][investigate + '_list']
                            if np.mean(scratch_list) > np.mean(pretrain_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                        except:
                            pass
                else:
                    result_string = '--'
                result_strings.append(result_string)
            if not flag_compare_pretrain_scratch:
                value_arg_sort = np.argsort(result_means)[::-1]
                # perform statistical test best with second best model
                stats,pvalue = scipy.stats.ttest_ind(result_lists[value_arg_sort[0]],result_lists[value_arg_sort[1]])

                if pvalue < pval:
                    result_strings[value_arg_sort[0]] += '$\dagger$'
                result_strings[value_arg_sort[0]] = '\\textbf{' + result_strings[value_arg_sort[0]] + '}'
            number_string = ' & '.join(result_strings)
            cur_str += ' &' + number_string + '\\\\'
            print(cur_str)
            
    print('################################################')
    print('#')
    print('# PRINT TABLE ONLY MSE')
    print('#')
    print('################################################')    
    mse_investigate_list = ['MSE']
    for investigate in mse_investigate_list:
        print('investigate: ' + str(investigate))
        num_trains = result_table_dict.keys()
        for num_train in num_trains:
            cur_str = ''#metric_mapping_dict[investigate]
            if num_train is None:
                display_number = 'all'
            else:
                display_number = str(num_train)
            cur_str += display_number #' & ' + display_number
            cur_results = result_table_dict[num_train]        
            result_lists = []
            result_means = []
            restult_std_errors = []
            result_strings = []
            for model in model_names:
                if model not in cur_results:
                    continue
                model_res = cur_results[model]
                if len(model_res) > 0:
                    cur_list = model_res[investigate + '_list']
                    result_lists.append(cur_list)
                    result_means.append(np.mean(cur_list))
                    restult_std_errors.append(np.std(cur_list) / np.sqrt(len(cur_list)))
                    result_string = str(np.round(np.mean(cur_list),decimals = decs)) +\
                                ' $\pm$ ' + str(np.round(np.std(cur_list) / np.sqrt(len(cur_list)),decimals = decs))
                    if 'pretrain' in model and model.replace('pretrain','scratch') in model_names:
                        pretrain_list = cur_list
                        try:
                            scratch_list = cur_results[model.replace('pretrain','scratch')][investigate + '_list']
                            if np.mean(pretrain_list) > np.mean(scratch_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                                # perform statistical test to compare pretrain with scratch version
                                stats,pvalue = scipy.stats.ttest_ind(pretrain_list,scratch_list)
                                
                                if pvalue < pval:
                                    result_string += '*'
                        except:
                            pass
                    if 'scratch' in model and model.replace('pretrain','scratch') in model_names:
                        scratch_list = cur_list
                        try:
                            pretrain_list = cur_results[model.replace('scratch','pretrain')][investigate + '_list']
                            if np.mean(scratch_list) > np.mean(pretrain_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                        except:
                            pass
                else:
                    result_string = '--'
                result_strings.append(result_string)
            if not flag_compare_pretrain_scratch:
                value_arg_sort = np.argsort(result_means)[::-1]
                # perform statistical test best with second best model
                stats,pvalue = scipy.stats.ttest_ind(result_lists[value_arg_sort[0]],result_lists[value_arg_sort[1]])

                if pvalue < pval:
                    result_strings[value_arg_sort[0]] += '$\dagger$'
                result_strings[value_arg_sort[0]] = '\\textbf{' + result_strings[value_arg_sort[0]] + '}'
            number_string = ' & '.join(result_strings)
            cur_str += ' &' + number_string + '\\\\'
            print(cur_str)
    
    print('################################################')
    print('#')
    print('# PLOT FIGURE')
    print('#')
    print('################################################')
    
    use_model_names = ['nn_baseline_scratch',                 
                 'nn_paccmann_scratch',
                 'tDNN_scratch',
                 'nn_baseline_pretrain',
                 'nn_paccmann_pretrain',                
                 'tDNN_pretrain']
    for investigate in investigate_list:
        fig_filename = 'plots/' + save_fig_prefix + train_mode + '_'+ target + '_' + investigate + '.pdf'
        fig_filename_png = fig_filename.replace('.pdf','.png')
        min_val = 1000
        max_val = -10000
        for model_name in use_model_names:
            if model_name not in result_table_dict[list(num_trains)[0]]:
                continue
            display_name = model_mapping_dict[model_name]
            mean_vals = []
            std_err_vals = []
            key_vals = []
            x_ticks  = []
            counter = 0
            for num_train in num_trains:
                try:
                    cur_vals = result_table_dict[num_train][model_name][investigate + '_list']
                    mean_vals.append(np.mean(cur_vals))
                    std_err_vals.append(np.std(cur_vals) / np.sqrt(len(cur_vals)))
                    display_key = num_train
                    if display_key == list(num_trains)[-1]:
                        display_key = 'all'
                    key_vals.append(display_key)
                    x_ticks.append(counter)
                except:
                    pass
                counter += 1
            plt.errorbar(x_ticks,mean_vals,std_err_vals,label=display_name)
            if np.min(mean_vals) < min_val:
                min_val = np.min(mean_vals)
            if np.max(mean_vals) > max_val:
                max_val = np.max(mean_vals)
        plt.xticks(np.arange(len(num_trains)),key_vals)
        plt.xlabel('Number of used examples for target data set')
        plt.ylabel(metric_mapping_dict[investigate]) 
        plt.legend(ncol=2,loc=2)
        plt.ylim([min_val,max_val + 0.2])
        plt.savefig(fig_filename)
        plt.savefig(fig_filename_png,dpi=600)        
        plt.show()
# Out:
# cur_load_path: results/gdsc_ccle_0_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_10_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_50_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_100_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_500_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_1000_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_5000_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_ccle_10000_True_precision_oncology_ensemble.joblib
# source: gdsc
# target: ccle
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_lab
# 0 &-- & 0.588 $\pm$ 0.012 & -- & 0.572 $\pm$ 0.006 & -- & 0.593 $\pm$ 0.009\\
# 10 &0.082 $\pm$ 0.028 & \textbf{0.491 $\pm$ 0.024}* & 0.112 $\pm$ 0.055 & \textbf{0.565 $\pm$ 0.013}* & 0.231 $\pm$ 0.043 & \textbf{0.53 $\pm$ 0.048}*\\
# 50 &0.148 $\pm$ 0.023 & \textbf{0.636 $\pm$ 0.01}* & -0.025 $\pm$ 0.07 & \textbf{0.613 $\pm$ 0.01}* & 0.474 $\pm$ 0.024 & \textbf{0.576 $\pm$ 0.022}*\\
# 100 &0.263 $\pm$ 0.03 & \textbf{0.682 $\pm$ 0.014}* & 0.097 $\pm$ 0.039 & \textbf{0.651 $\pm$ 0.011}* & 0.541 $\pm$ 0.021 & \textbf{0.59 $\pm$ 0.022}\\
# 500 &0.687 $\pm$ 0.005 & \textbf{0.76 $\pm$ 0.005}* & 0.536 $\pm$ 0.042 & \textbf{0.743 $\pm$ 0.005}* & \textbf{0.729 $\pm$ 0.007} & 0.697 $\pm$ 0.009\\
# 1000 &0.738 $\pm$ 0.005 & \textbf{0.777 $\pm$ 0.006}* & \textbf{0.749 $\pm$ 0.009} & 0.741 $\pm$ 0.006 & \textbf{0.757 $\pm$ 0.005} & 0.691 $\pm$ 0.011\\
# 5000 &0.766 $\pm$ 0.004 & \textbf{0.792 $\pm$ 0.005}* & 0.739 $\pm$ 0.005 & \textbf{0.743 $\pm$ 0.008} & \textbf{0.772 $\pm$ 0.005} & 0.714 $\pm$ 0.01\\
# 10000 &0.762 $\pm$ 0.008 & \textbf{0.793 $\pm$ 0.006}* & \textbf{0.739 $\pm$ 0.007} & 0.729 $\pm$ 0.005 & \textbf{0.781 $\pm$ 0.005} & 0.721 $\pm$ 0.006\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.166 $\pm$ 0.003 & -- & 0.176 $\pm$ 0.003 & -- & 0.158 $\pm$ 0.002\\
# 10 &0.595 $\pm$ 0.074 & \textbf{2.069 $\pm$ 1.017} & \textbf{0.582 $\pm$ 0.053} & 0.166 $\pm$ 0.004 & \textbf{0.242 $\pm$ 0.025} & 0.145 $\pm$ 0.009\\
# 50 &\textbf{0.499 $\pm$ 0.084} & 0.129 $\pm$ 0.003 & \textbf{0.696 $\pm$ 0.071} & 0.144 $\pm$ 0.004 & \textbf{0.19 $\pm$ 0.005} & 0.137 $\pm$ 0.007\\
# 100 &\textbf{0.532 $\pm$ 0.077} & 0.11 $\pm$ 0.004 & \textbf{0.479 $\pm$ 0.047} & 0.13 $\pm$ 0.004 & \textbf{0.172 $\pm$ 0.004} & 0.136 $\pm$ 0.011\\
# 500 &\textbf{0.277 $\pm$ 0.023} & 0.086 $\pm$ 0.002 & \textbf{0.283 $\pm$ 0.06} & 0.092 $\pm$ 0.002 & 0.104 $\pm$ 0.002 & \textbf{0.109 $\pm$ 0.002}\\
# 1000 &\textbf{0.131 $\pm$ 0.006} & 0.081 $\pm$ 0.002 & \textbf{0.101 $\pm$ 0.009} & 0.092 $\pm$ 0.002 & 0.093 $\pm$ 0.002 & \textbf{0.114 $\pm$ 0.004}*\\
# 5000 &\textbf{0.083 $\pm$ 0.002} & 0.076 $\pm$ 0.002 & 0.092 $\pm$ 0.002 & \textbf{0.093 $\pm$ 0.003} & 0.085 $\pm$ 0.002 & \textbf{0.109 $\pm$ 0.004}*\\
# 10000 &\textbf{0.085 $\pm$ 0.002} & 0.074 $\pm$ 0.002 & 0.094 $\pm$ 0.002 & \textbf{0.097 $\pm$ 0.003} & 0.08 $\pm$ 0.002 & \textbf{0.108 $\pm$ 0.003}*\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_pancreas_0_True_precision_oncology_ensemble.joblib
# does not exist
# cur_load_path: results/gdsc_pancreas_10_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_50_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_100_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_500_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_10000_True_precision_oncology_ensemble.joblib
# does not exist
# source: gdsc
# target: pancreas
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_lab
# 10 &0.021 $\pm$ 0.035 & \textbf{0.477 $\pm$ 0.033}* & -0.007 $\pm$ 0.03 & \textbf{0.476 $\pm$ 0.022}* & 0.126 $\pm$ 0.026 & \textbf{0.64 $\pm$ 0.022}*\\
# 50 &0.213 $\pm$ 0.041 & \textbf{0.635 $\pm$ 0.021}* & 0.019 $\pm$ 0.031 & \textbf{0.645 $\pm$ 0.032}* & 0.592 $\pm$ 0.029 & \textbf{0.756 $\pm$ 0.019}*\\
# 100 &0.39 $\pm$ 0.036 & \textbf{0.727 $\pm$ 0.021}* & 0.016 $\pm$ 0.029 & \textbf{0.717 $\pm$ 0.016}* & 0.768 $\pm$ 0.016 & \textbf{0.773 $\pm$ 0.019}\\
# 500 &\textbf{0.885 $\pm$ 0.01} & 0.849 $\pm$ 0.017 & 0.514 $\pm$ 0.074 & \textbf{0.842 $\pm$ 0.018}* & \textbf{0.898 $\pm$ 0.009} & 0.817 $\pm$ 0.01\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 10 &\textbf{0.503 $\pm$ 0.061} & 0.072 $\pm$ 0.01 & \textbf{0.464 $\pm$ 0.043} & 0.05 $\pm$ 0.002 & \textbf{0.054 $\pm$ 0.003} & 0.03 $\pm$ 0.002\\
# 50 &\textbf{0.51 $\pm$ 0.099} & 0.035 $\pm$ 0.005 & \textbf{0.519 $\pm$ 0.051} & 0.035 $\pm$ 0.003 & \textbf{0.04 $\pm$ 0.003} & 0.022 $\pm$ 0.002\\
# 100 &\textbf{0.524 $\pm$ 0.14} & 0.024 $\pm$ 0.002 & \textbf{0.457 $\pm$ 0.044} & 0.032 $\pm$ 0.003 & \textbf{0.028 $\pm$ 0.003} & 0.02 $\pm$ 0.002\\
# 500 &\textbf{0.217 $\pm$ 0.045} & 0.015 $\pm$ 0.002 & \textbf{0.163 $\pm$ 0.039} & 0.015 $\pm$ 0.001 & \textbf{0.025 $\pm$ 0.005} & 0.017 $\pm$ 0.001\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_xenografts_0_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_10_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_50_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_10000_True_precision_oncology_ensemble.joblib
# source: gdsc
# target: xenografts
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_lab
# 0 &-- & 0.56 $\pm$ 0.114 & -- & 0.648 $\pm$ 0.109 & -- & 0.639 $\pm$ 0.151\\
# 10 &0.067 $\pm$ 0.156 & \textbf{0.359 $\pm$ 0.168} & 0.268 $\pm$ 0.161 & \textbf{0.511 $\pm$ 0.122} & \textbf{0.204 $\pm$ 0.145} & 0.2 $\pm$ 0.182\\
# 50 &0.425 $\pm$ 0.155 & \textbf{0.499 $\pm$ 0.145} & 0.178 $\pm$ 0.185 & \textbf{0.577 $\pm$ 0.12} & \textbf{0.58 $\pm$ 0.134} & 0.452 $\pm$ 0.132\\
# 10000 &0.597 $\pm$ 0.112 & \textbf{0.661 $\pm$ 0.113} & 0.301 $\pm$ 0.181 & \textbf{0.585 $\pm$ 0.103} & \textbf{0.655 $\pm$ 0.131} & -0.004 $\pm$ 0.159\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.31 $\pm$ 0.03 & -- & 0.316 $\pm$ 0.029 & -- & 0.285 $\pm$ 0.02\\
# 10 &0.271 $\pm$ 0.077 & \textbf{18.422 $\pm$ 9.813} & 0.168 $\pm$ 0.024 & \textbf{0.309 $\pm$ 0.021}* & 0.078 $\pm$ 0.015 & \textbf{0.138 $\pm$ 0.029}\\
# 50 &\textbf{0.221 $\pm$ 0.068} & 0.115 $\pm$ 0.034 & 0.154 $\pm$ 0.034 & \textbf{0.25 $\pm$ 0.021}* & 0.041 $\pm$ 0.011 & \textbf{0.067 $\pm$ 0.012}\\
# 10000 &\textbf{0.197 $\pm$ 0.041} & 0.085 $\pm$ 0.023 & 0.165 $\pm$ 0.034 & \textbf{0.197 $\pm$ 0.021} & 0.041 $\pm$ 0.012 & \textbf{0.081 $\pm$ 0.016}\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_beat_aml_0_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_10_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_50_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_100_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_500_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_1000_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_5000_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_10000_True_precision_oncology_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_20000_True_precision_oncology_ensemble.joblib
# does not exist
# source: gdsc
# target: beat_aml
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_lab
# 0 &-- & 0.202 $\pm$ 0.014 & -- & 0.245 $\pm$ 0.008 & -- & 0.255 $\pm$ 0.011\\
# 10 &-0.003 $\pm$ 0.014 & \textbf{0.165 $\pm$ 0.012}* & -0.017 $\pm$ 0.027 & \textbf{0.235 $\pm$ 0.012}* & -0.036 $\pm$ 0.022 & \textbf{0.165 $\pm$ 0.031}*\\
# 50 &0.028 $\pm$ 0.017 & \textbf{0.223 $\pm$ 0.014}* & 0.02 $\pm$ 0.035 & \textbf{0.227 $\pm$ 0.01}* & 0.087 $\pm$ 0.019 & \textbf{0.185 $\pm$ 0.027}*\\
# 100 &0.022 $\pm$ 0.012 & \textbf{0.275 $\pm$ 0.017}* & 0.027 $\pm$ 0.022 & \textbf{0.26 $\pm$ 0.009}* & 0.18 $\pm$ 0.019 & \textbf{0.255 $\pm$ 0.022}*\\
# 500 &0.337 $\pm$ 0.012 & \textbf{0.486 $\pm$ 0.012}* & 0.095 $\pm$ 0.029 & \textbf{0.448 $\pm$ 0.018}* & \textbf{0.547 $\pm$ 0.009} & 0.357 $\pm$ 0.02\\
# 1000 &0.497 $\pm$ 0.015 & \textbf{0.551 $\pm$ 0.012}* & 0.207 $\pm$ 0.022 & \textbf{0.523 $\pm$ 0.01}* & \textbf{0.615 $\pm$ 0.008} & 0.419 $\pm$ 0.015\\
# 5000 &\textbf{0.682 $\pm$ 0.006} & 0.654 $\pm$ 0.01 & \textbf{0.66 $\pm$ 0.01} & 0.64 $\pm$ 0.007 & \textbf{0.66 $\pm$ 0.009} & 0.49 $\pm$ 0.016\\
# 10000 &\textbf{0.682 $\pm$ 0.012} & 0.67 $\pm$ 0.01 & \textbf{0.686 $\pm$ 0.008} & 0.657 $\pm$ 0.01 & \textbf{0.674 $\pm$ 0.009} & 0.538 $\pm$ 0.016\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.072 $\pm$ 0.002 & -- & 0.074 $\pm$ 0.003 & -- & 0.075 $\pm$ 0.003\\
# 10 &\textbf{0.828 $\pm$ 0.149} & 0.787 $\pm$ 0.316 & \textbf{0.627 $\pm$ 0.091} & 0.067 $\pm$ 0.004 & \textbf{0.11 $\pm$ 0.028} & 0.066 $\pm$ 0.006\\
# 50 &\textbf{0.647 $\pm$ 0.094} & 0.076 $\pm$ 0.005 & \textbf{0.571 $\pm$ 0.044} & 0.06 $\pm$ 0.003 & \textbf{0.137 $\pm$ 0.069} & 0.074 $\pm$ 0.005\\
# 100 &0.508 $\pm$ 0.088 & \textbf{1.537 $\pm$ 1.403} & \textbf{0.561 $\pm$ 0.104} & 0.056 $\pm$ 0.002 & \textbf{0.118 $\pm$ 0.056} & 0.07 $\pm$ 0.003\\
# 500 &\textbf{0.198 $\pm$ 0.025} & 0.06 $\pm$ 0.019 & \textbf{0.338 $\pm$ 0.072} & 0.04 $\pm$ 0.001 & \textbf{0.069 $\pm$ 0.023} & 0.067 $\pm$ 0.007\\
# 1000 &\textbf{0.281 $\pm$ 0.166} & 0.212 $\pm$ 0.149 & \textbf{0.083 $\pm$ 0.012} & 0.035 $\pm$ 0.001 & \textbf{0.082 $\pm$ 0.038} & 0.058 $\pm$ 0.003\\
# 5000 &0.027 $\pm$ 0.001 & \textbf{0.047 $\pm$ 0.013} & 0.028 $\pm$ 0.001 & \textbf{0.031 $\pm$ 0.001} & 0.048 $\pm$ 0.011 & \textbf{0.064 $\pm$ 0.011}\\
# 10000 &0.028 $\pm$ 0.001 & \textbf{0.029 $\pm$ 0.001} & 0.027 $\pm$ 0.001 & \textbf{0.03 $\pm$ 0.001} & \textbf{0.064 $\pm$ 0.024} & 0.06 $\pm$ 0.016\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################

# %% [markdown]
# ## Drug Development

# %%
save_dir = 'results/'
save_prefix = ''
source = 'gdsc'
targets = ['ccle','pancreas','xenografts','beat_aml']
target_number_mapping = {'ccle':[0,10,50,100,500,1000,5000,10000],
                         'pancreas':[0,10,50,100,500,10000],
                         'beat_aml':[0,10,50,100,500,1000,5000,10000,20000],
                         'xenografts':[0,10,50,10000]}

flag_compare_pretrain_scratch = True
flag_normalize_descriptors = True
train_mode = 'drug_development'
use_netpop = 'ensemble'
save_fig_prefix = 'only_pretrain_'

investigate_list = ['pearson_inhib']#'pearson_inhib',]#'pearson','pearson_inhib','spearman','spearman_inhib']
metric_mapping_dict = {'pearson':'Pearson correlation',
                      'pearson_inhib':'Per-inhibitor pearson correlation',
                      'spearman':'Spearman correlation',
                      'spearman_inhib':'Per-inhibitor spearman correlation',
                      'pearson_lab': 'Per-specimen pearson correlation'}

model_mapping_dict = {'nn_baseline_scratch' :'Conv NN [scratch]',
                      'nn_baseline_pretrain':'Conv NN [pre-train]',
                      'nn_paccmann_scratch' : 'PaccMann [scratch]',
                      'nn_paccmann_pretrain' :'PaccMann [pre-train]',
                      'rf':'Random Forest',
                      'tDNN_scratch': 'tDNN [scratch]',
                      'tDNN_pretrain': 'tDNN [pre-train]'}


model_names = ['nn_baseline_scratch', 'nn_baseline_pretrain', 
               'nn_paccmann_scratch', 'nn_paccmann_pretrain',
               'tDNN_scratch', 'tDNN_pretrain',
              # 'rf',
              ]

investigate_list_small = ['pearson_inhib']#['pearson_inhib','pearson_lab']

# plot params
pval = 0.05 #p-value for ttest
decs = 3
invers_scale_list = [False]

for target in targets:
    use_samples_list = target_number_mapping[target]
    list_use_samples = []
    all_result_dicts = []
    for use_samples in use_samples_list:
        cur_load_path = save_dir +  save_prefix + source + '_' + target + '_' + str(use_samples) +\
                '_' + str(flag_normalize_descriptors) + '_' + str(train_mode) + '_' + str(use_netpop) + '.joblib'
        print('cur_load_path: ' + cur_load_path)
        if not os.path.exists(cur_load_path):
            print('does not exist')
            continue
        cur_tmp_dict = joblib.load(cur_load_path)
        all_result_dicts.append(cur_tmp_dict)
        list_use_samples.append(use_samples)
    
    print('source: ' + str(source))
    print('target: ' + str(target))
    result_table_dict = dict()
    keys = np.arange(len(all_result_dicts))
    for j in tqdm(np.arange(len(keys))):
        cur_key = list_use_samples[j]
        if cur_key not in result_table_dict:
            result_table_dict[cur_key] = dict()
        cur_num_train_results = all_result_dicts[j]
        model_keys = model_mapping_dict.keys()
        for model_key in model_keys:
            if model_key not in result_table_dict[cur_key]:
                result_table_dict[cur_key][model_key] = dict()
            if model_key in cur_num_train_results:
                cur_model_results = cur_num_train_results[model_key]
                min_max_scaler = None
                if 'min_max_scaler' in cur_num_train_results:
                    min_max_scaler = cur_num_train_results['min_max_scaler']
                tmp_res_dict = evaluation.get_metric_dict(cur_model_results['pred_complete'], cur_model_results['gt_complete'],
                                            cur_model_results['inhib_data_complete'],cur_model_results['lab_data_complete'],
                                            min_max_scaler, invers_scale_list = invers_scale_list,
                                            flag_calc_per_lab = False,
                                            flag_calc_per_inhib = True)

                tmp_res_keys = tmp_res_dict.keys()
                for key in tmp_res_keys:
                    result_table_dict[cur_key][model_key][key] = tmp_res_dict[key]
            

    print('################################################')
    print('#')
    print('# PRINT TABLE ONLY PEARSON')
    print('#')
    print('################################################')    

    for investigate in investigate_list_small:
        print('investigate: ' + str(investigate))
        num_trains = result_table_dict.keys()
        for num_train in num_trains:
            cur_str = ''#metric_mapping_dict[investigate]
            if num_train is None:
                display_number = 'all'
            else:
                display_number = str(num_train)
            cur_str += display_number #' & ' + display_number
            cur_results = result_table_dict[num_train]        
            result_lists = []
            result_means = []
            restult_std_errors = []
            result_strings = []
            for model in model_names:
                if model not in cur_results:
                    continue
                model_res = cur_results[model]
                if len(model_res) > 0:
                    cur_list = model_res[investigate + '_list']
                    result_lists.append(cur_list)
                    result_means.append(np.mean(cur_list))
                    restult_std_errors.append(np.std(cur_list) / np.sqrt(len(cur_list)))
                    result_string = str(np.round(np.mean(cur_list),decimals = decs)) +\
                                ' $\pm$ ' + str(np.round(np.std(cur_list) / np.sqrt(len(cur_list)),decimals = decs))
                    if 'pretrain' in model and model.replace('pretrain','scratch') in model_names:
                        pretrain_list = cur_list
                        try:
                            scratch_list = cur_results[model.replace('pretrain','scratch')][investigate + '_list']
                            if np.mean(pretrain_list) > np.mean(scratch_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                                # perform statistical test to compare pretrain with scratch version
                                stats,pvalue = scipy.stats.ttest_ind(pretrain_list,scratch_list)
                                
                                if pvalue < pval:
                                    result_string += '*'
                        except:
                            pass
                    if 'scratch' in model and model.replace('pretrain','scratch') in model_names:
                        scratch_list = cur_list
                        try:
                            pretrain_list = cur_results[model.replace('scratch','pretrain')][investigate + '_list']
                            if np.mean(scratch_list) > np.mean(pretrain_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                        except:
                            pass
                else:
                    result_string = '--'
                result_strings.append(result_string)
            if not flag_compare_pretrain_scratch:
                value_arg_sort = np.argsort(result_means)[::-1]
                # perform statistical test best with second best model
                stats,pvalue = scipy.stats.ttest_ind(result_lists[value_arg_sort[0]],result_lists[value_arg_sort[1]])

                if pvalue < pval:
                    result_strings[value_arg_sort[0]] += '$\dagger$'
                result_strings[value_arg_sort[0]] = '\\textbf{' + result_strings[value_arg_sort[0]] + '}'
            number_string = ' & '.join(result_strings)
            cur_str += ' &' + number_string + '\\\\'
            print(cur_str)
            
    print('################################################')
    print('#')
    print('# PRINT TABLE ONLY MSE')
    print('#')
    print('################################################')    
    mse_investigate_list = ['MSE']
    for investigate in mse_investigate_list:
        print('investigate: ' + str(investigate))
        num_trains = result_table_dict.keys()
        for num_train in num_trains:
            cur_str = ''#metric_mapping_dict[investigate]
            if num_train is None:
                display_number = 'all'
            else:
                display_number = str(num_train)
            cur_str += display_number #' & ' + display_number
            cur_results = result_table_dict[num_train]        
            result_lists = []
            result_means = []
            restult_std_errors = []
            result_strings = []
            for model in model_names:
                if model not in cur_results:
                    continue
                model_res = cur_results[model]
                if len(model_res) > 0:
                    cur_list = model_res[investigate + '_list']
                    result_lists.append(cur_list)
                    result_means.append(np.mean(cur_list))
                    restult_std_errors.append(np.std(cur_list) / np.sqrt(len(cur_list)))
                    result_string = str(np.round(np.mean(cur_list),decimals = decs)) +\
                                ' $\pm$ ' + str(np.round(np.std(cur_list) / np.sqrt(len(cur_list)),decimals = decs))
                    if 'pretrain' in model and model.replace('pretrain','scratch') in model_names:
                        pretrain_list = cur_list
                        try:
                            scratch_list = cur_results[model.replace('pretrain','scratch')][investigate + '_list']
                            if np.mean(pretrain_list) > np.mean(scratch_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                                # perform statistical test to compare pretrain with scratch version
                                stats,pvalue = scipy.stats.ttest_ind(pretrain_list,scratch_list)
                                
                                if pvalue < pval:
                                    result_string += '*'
                        except:
                            pass
                    if 'scratch' in model and model.replace('pretrain','scratch') in model_names:
                        scratch_list = cur_list
                        try:
                            pretrain_list = cur_results[model.replace('scratch','pretrain')][investigate + '_list']
                            if np.mean(scratch_list) > np.mean(pretrain_list):
                                if flag_compare_pretrain_scratch:
                                    result_string = '\\textbf{' + result_string + '}'
                        except:
                            pass
                else:
                    result_string = '--'
                result_strings.append(result_string)
            if not flag_compare_pretrain_scratch:
                value_arg_sort = np.argsort(result_means)[::-1]
                # perform statistical test best with second best model
                stats,pvalue = scipy.stats.ttest_ind(result_lists[value_arg_sort[0]],result_lists[value_arg_sort[1]])

                if pvalue < pval:
                    result_strings[value_arg_sort[0]] += '$\dagger$'
                result_strings[value_arg_sort[0]] = '\\textbf{' + result_strings[value_arg_sort[0]] + '}'
            number_string = ' & '.join(result_strings)
            cur_str += ' &' + number_string + '\\\\'
            print(cur_str)
    
    
    print('################################################')
    print('#')
    print('# PLOT FIGURE')
    print('#')
    print('################################################')
    
    use_model_names = ['nn_baseline_scratch',                 
                 'nn_paccmann_scratch',
                 'tDNN_scratch',
                 'nn_baseline_pretrain',
                 'nn_paccmann_pretrain',                
                 'tDNN_pretrain']
    for investigate in investigate_list:
        fig_filename = 'plots/' + save_fig_prefix + train_mode + '_'+ target + '_' + investigate + '.pdf'
        fig_filename_png = fig_filename.replace('.pdf','.png')
        min_val = 1000
        max_val = -10000
        for model_name in use_model_names:
            if model_name not in result_table_dict[list(num_trains)[0]]:
                continue
            display_name = model_mapping_dict[model_name]
            mean_vals = []
            std_err_vals = []
            key_vals = []
            x_ticks  = []
            counter = 0
            for num_train in num_trains:
                try:
                    cur_vals = result_table_dict[num_train][model_name][investigate + '_list']
                    mean_vals.append(np.mean(cur_vals))
                    std_err_vals.append(np.std(cur_vals) / np.sqrt(len(cur_vals)))
                    display_key = num_train
                    if display_key == list(num_trains)[-1]:
                        display_key = 'all'
                    key_vals.append(display_key)
                    x_ticks.append(counter)
                except:
                    pass
                counter += 1
            plt.errorbar(x_ticks,mean_vals,std_err_vals,label=display_name)
            if np.min(mean_vals) < min_val:
                min_val = np.min(mean_vals)
            if np.max(mean_vals) > max_val:
                max_val = np.max(mean_vals)
        plt.xticks(np.arange(len(num_trains)),key_vals)
        plt.xlabel('Number of used examples for target data set')
        plt.ylabel(metric_mapping_dict[investigate]) 
        plt.legend(ncol=2,loc=2)
        plt.ylim([min_val,max_val + 0.2])
        plt.savefig(fig_filename)
        plt.savefig(fig_filename_png,dpi=600)
        plt.show()
# Out:
# cur_load_path: results/gdsc_ccle_0_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_10_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_50_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_100_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_500_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_1000_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_5000_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_ccle_10000_True_drug_development_ensemble.joblib
# source: gdsc
# target: ccle
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_inhib
# 0 &-- & 0.093 $\pm$ 0.02 & -- & 0.057 $\pm$ 0.014 & -- & 0.2 $\pm$ 0.034\\
# 10 &-0.019 $\pm$ 0.018 & \textbf{0.089 $\pm$ 0.027}* & -0.004 $\pm$ 0.016 & \textbf{0.05 $\pm$ 0.012}* & 0.03 $\pm$ 0.014 & \textbf{0.194 $\pm$ 0.034}*\\
# 50 &0.008 $\pm$ 0.013 & \textbf{0.104 $\pm$ 0.016}* & -0.006 $\pm$ 0.01 & \textbf{0.064 $\pm$ 0.018}* & 0.027 $\pm$ 0.024 & \textbf{0.125 $\pm$ 0.03}*\\
# 100 &0.007 $\pm$ 0.012 & \textbf{0.08 $\pm$ 0.023}* & -0.006 $\pm$ 0.015 & \textbf{0.076 $\pm$ 0.014}* & 0.061 $\pm$ 0.018 & \textbf{0.176 $\pm$ 0.035}*\\
# 500 &0.085 $\pm$ 0.011 & \textbf{0.123 $\pm$ 0.018} & 0.015 $\pm$ 0.015 & \textbf{0.125 $\pm$ 0.017}* & 0.122 $\pm$ 0.013 & \textbf{0.206 $\pm$ 0.032}*\\
# 1000 &0.139 $\pm$ 0.011 & \textbf{0.145 $\pm$ 0.02} & 0.073 $\pm$ 0.019 & \textbf{0.098 $\pm$ 0.015} & \textbf{0.17 $\pm$ 0.012} & 0.137 $\pm$ 0.033\\
# 5000 &\textbf{0.254 $\pm$ 0.016} & 0.218 $\pm$ 0.02 & \textbf{0.213 $\pm$ 0.018} & 0.143 $\pm$ 0.02 & \textbf{0.294 $\pm$ 0.019} & 0.193 $\pm$ 0.033\\
# 10000 &\textbf{0.289 $\pm$ 0.021} & 0.27 $\pm$ 0.024 & \textbf{0.26 $\pm$ 0.021} & 0.214 $\pm$ 0.017 & \textbf{0.346 $\pm$ 0.019} & 0.232 $\pm$ 0.027\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.203 $\pm$ 0.039 & -- & 0.209 $\pm$ 0.041 & -- & 0.171 $\pm$ 0.026\\
# 10 &\textbf{0.589 $\pm$ 0.09} & 0.333 $\pm$ 0.076 & \textbf{0.696 $\pm$ 0.09} & 0.198 $\pm$ 0.034 & \textbf{0.235 $\pm$ 0.041} & 0.192 $\pm$ 0.028\\
# 50 &\textbf{0.334 $\pm$ 0.034} & 0.234 $\pm$ 0.037 & \textbf{0.607 $\pm$ 0.086} & 0.19 $\pm$ 0.027 & \textbf{0.217 $\pm$ 0.022} & 0.188 $\pm$ 0.022\\
# 100 &\textbf{0.582 $\pm$ 0.081} & 0.222 $\pm$ 0.039 & \textbf{0.558 $\pm$ 0.075} & 0.197 $\pm$ 0.032 & \textbf{0.231 $\pm$ 0.021} & 0.197 $\pm$ 0.033\\
# 500 &\textbf{0.335 $\pm$ 0.034} & 0.212 $\pm$ 0.03 & \textbf{0.35 $\pm$ 0.07} & 0.22 $\pm$ 0.036 & \textbf{0.219 $\pm$ 0.017} & 0.202 $\pm$ 0.032\\
# 1000 &\textbf{0.252 $\pm$ 0.025} & 0.205 $\pm$ 0.02 & \textbf{0.224 $\pm$ 0.031} & 0.188 $\pm$ 0.028 & 0.198 $\pm$ 0.015 & \textbf{0.22 $\pm$ 0.026}\\
# 5000 &\textbf{0.212 $\pm$ 0.036} & 0.192 $\pm$ 0.034 & \textbf{0.284 $\pm$ 0.034} & 0.226 $\pm$ 0.033 & 0.174 $\pm$ 0.019 & \textbf{0.251 $\pm$ 0.041}\\
# 10000 &\textbf{0.209 $\pm$ 0.033} & 0.188 $\pm$ 0.026 & \textbf{0.253 $\pm$ 0.036} & 0.205 $\pm$ 0.029 & 0.164 $\pm$ 0.018 & \textbf{0.227 $\pm$ 0.035}\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_pancreas_0_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_10_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_50_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_100_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_500_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_pancreas_10000_True_drug_development_ensemble.joblib
# source: gdsc
# target: pancreas
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_inhib
# 0 &-- & -0.025 $\pm$ 0.015 & -- & -0.041 $\pm$ 0.044 & -- & -0.115 $\pm$ 0.027\\
# 10 &\textbf{0.058 $\pm$ 0.041} & -0.044 $\pm$ 0.021 & -0.005 $\pm$ 0.023 & \textbf{0.014 $\pm$ 0.042} & \textbf{0.105 $\pm$ 0.033} & -0.035 $\pm$ 0.042\\
# 50 &0.008 $\pm$ 0.043 & \textbf{0.041 $\pm$ 0.037} & -0.024 $\pm$ 0.032 & \textbf{0.048 $\pm$ 0.034} & \textbf{0.091 $\pm$ 0.032} & 0.044 $\pm$ 0.044\\
# 100 &0.046 $\pm$ 0.038 & \textbf{0.059 $\pm$ 0.029} & \textbf{0.044 $\pm$ 0.016} & -0.006 $\pm$ 0.024 & \textbf{0.185 $\pm$ 0.029} & 0.117 $\pm$ 0.035\\
# 500 &0.22 $\pm$ 0.032 & \textbf{0.243 $\pm$ 0.041} & 0.015 $\pm$ 0.035 & \textbf{0.12 $\pm$ 0.027}* & \textbf{0.411 $\pm$ 0.028} & 0.265 $\pm$ 0.021\\
# 10000 &0.251 $\pm$ 0.033 & \textbf{0.309 $\pm$ 0.028} & \textbf{0.163 $\pm$ 0.039} & 0.163 $\pm$ 0.027 & \textbf{0.437 $\pm$ 0.022} & 0.179 $\pm$ 0.053\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.058 $\pm$ 0.015 & -- & 0.064 $\pm$ 0.019 & -- & 0.054 $\pm$ 0.018\\
# 10 &\textbf{0.434 $\pm$ 0.076} & 0.186 $\pm$ 0.086 & \textbf{0.639 $\pm$ 0.07} & 0.057 $\pm$ 0.016 & \textbf{0.061 $\pm$ 0.012} & 0.049 $\pm$ 0.013\\
# 50 &\textbf{0.421 $\pm$ 0.064} & 0.049 $\pm$ 0.015 & \textbf{0.46 $\pm$ 0.052} & 0.051 $\pm$ 0.014 & \textbf{0.056 $\pm$ 0.01} & 0.043 $\pm$ 0.01\\
# 100 &\textbf{0.498 $\pm$ 0.104} & 0.05 $\pm$ 0.014 & \textbf{0.333 $\pm$ 0.051} & 0.053 $\pm$ 0.017 & \textbf{0.044 $\pm$ 0.011} & 0.043 $\pm$ 0.011\\
# 500 &\textbf{0.093 $\pm$ 0.023} & 0.041 $\pm$ 0.008 & \textbf{0.192 $\pm$ 0.058} & 0.042 $\pm$ 0.011 & 0.038 $\pm$ 0.013 & \textbf{0.063 $\pm$ 0.011}\\
# 10000 &\textbf{0.047 $\pm$ 0.016} & 0.044 $\pm$ 0.011 & \textbf{0.088 $\pm$ 0.026} & 0.039 $\pm$ 0.014 & 0.035 $\pm$ 0.011 & \textbf{0.058 $\pm$ 0.013}\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_xenografts_0_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_10_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_50_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_xenografts_10000_True_drug_development_ensemble.joblib
# source: gdsc
# target: xenografts
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_inhib
# 0 &-- & 0.043 $\pm$ 0.129 & -- & 0.082 $\pm$ 0.014 & -- & 0.048 $\pm$ 0.154\\
# 10 &-0.024 $\pm$ 0.04 & \textbf{-0.014 $\pm$ 0.172} & -0.193 $\pm$ 0.062 & \textbf{0.096 $\pm$ 0.198} & -0.175 $\pm$ 0.047 & \textbf{-0.047 $\pm$ 0.041}\\
# 50 &-0.143 $\pm$ 0.101 & \textbf{-0.084 $\pm$ 0.14} & \textbf{0.258 $\pm$ 0.172} & -0.015 $\pm$ 0.084 & \textbf{-0.101 $\pm$ 0.117} & -0.124 $\pm$ 0.213\\
# 10000 &-0.187 $\pm$ 0.057 & \textbf{-0.184 $\pm$ 0.125} & \textbf{0.047 $\pm$ 0.077} & -0.021 $\pm$ 0.169 & -0.278 $\pm$ 0.179 & \textbf{-0.216 $\pm$ 0.089}\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.332 $\pm$ 0.03 & -- & 0.295 $\pm$ 0.044 & -- & 0.23 $\pm$ 0.067\\
# 10 &0.269 $\pm$ 0.107 & \textbf{566.705 $\pm$ 452.189} & 0.149 $\pm$ 0.056 & \textbf{0.275 $\pm$ 0.084} & 0.1 $\pm$ 0.019 & \textbf{0.118 $\pm$ 0.033}\\
# 50 &0.097 $\pm$ 0.002 & \textbf{3.928 $\pm$ 3.121} & 0.077 $\pm$ 0.014 & \textbf{0.328 $\pm$ 0.071}* & 0.088 $\pm$ 0.005 & \textbf{0.143 $\pm$ 0.034}\\
# 10000 &0.1 $\pm$ 0.029 & \textbf{0.384 $\pm$ 0.103} & 0.188 $\pm$ 0.063 & \textbf{0.285 $\pm$ 0.071} & 0.112 $\pm$ 0.003 & \textbf{0.173 $\pm$ 0.052}\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
# cur_load_path: results/gdsc_beat_aml_0_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_10_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_50_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_100_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_500_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_1000_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_5000_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_10000_True_drug_development_ensemble.joblib
# cur_load_path: results/gdsc_beat_aml_20000_True_drug_development_ensemble.joblib
# does not exist
# source: gdsc
# target: beat_aml
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ################################################
# #
# # PRINT TABLE ONLY PEARSON
# #
# ################################################
# investigate: pearson_inhib
# 0 &-- & 0.071 $\pm$ 0.008 & -- & 0.004 $\pm$ 0.017 & -- & 0.04 $\pm$ 0.011\\
# 10 &-0.003 $\pm$ 0.019 & \textbf{0.025 $\pm$ 0.01} & -0.016 $\pm$ 0.006 & \textbf{0.045 $\pm$ 0.01}* & \textbf{0.053 $\pm$ 0.016} & 0.052 $\pm$ 0.011\\
# 50 &-0.002 $\pm$ 0.016 & \textbf{0.043 $\pm$ 0.009}* & -0.012 $\pm$ 0.009 & \textbf{0.037 $\pm$ 0.006}* & \textbf{0.05 $\pm$ 0.008} & 0.022 $\pm$ 0.007\\
# 100 &-0.01 $\pm$ 0.019 & \textbf{0.049 $\pm$ 0.012}* & 0.002 $\pm$ 0.006 & \textbf{0.032 $\pm$ 0.011}* & \textbf{0.081 $\pm$ 0.011} & 0.013 $\pm$ 0.015\\
# 500 &0.089 $\pm$ 0.015 & \textbf{0.122 $\pm$ 0.013} & 0.017 $\pm$ 0.01 & \textbf{0.072 $\pm$ 0.005}* & \textbf{0.23 $\pm$ 0.016} & 0.086 $\pm$ 0.011\\
# 1000 &0.186 $\pm$ 0.018 & \textbf{0.196 $\pm$ 0.011} & 0.015 $\pm$ 0.02 & \textbf{0.162 $\pm$ 0.012}* & \textbf{0.295 $\pm$ 0.016} & 0.133 $\pm$ 0.015\\
# 5000 &\textbf{0.371 $\pm$ 0.01} & 0.321 $\pm$ 0.015 & \textbf{0.385 $\pm$ 0.013} & 0.288 $\pm$ 0.013 & \textbf{0.379 $\pm$ 0.013} & 0.16 $\pm$ 0.016\\
# 10000 &\textbf{0.372 $\pm$ 0.015} & 0.345 $\pm$ 0.015 & \textbf{0.394 $\pm$ 0.017} & 0.34 $\pm$ 0.013 & \textbf{0.397 $\pm$ 0.015} & 0.236 $\pm$ 0.017\\
# ################################################
# #
# # PRINT TABLE ONLY MSE
# #
# ################################################
# investigate: MSE
# 0 &-- & 0.064 $\pm$ 0.007 & -- & 0.076 $\pm$ 0.005 & -- & 0.067 $\pm$ 0.005\\
# 10 &\textbf{0.594 $\pm$ 0.055} & 0.363 $\pm$ 0.13 & \textbf{0.546 $\pm$ 0.069} & 0.072 $\pm$ 0.006 & \textbf{0.125 $\pm$ 0.013} & 0.053 $\pm$ 0.005\\
# 50 &\textbf{0.58 $\pm$ 0.078} & 0.089 $\pm$ 0.012 & \textbf{0.591 $\pm$ 0.084} & 0.067 $\pm$ 0.005 & \textbf{0.108 $\pm$ 0.01} & 0.064 $\pm$ 0.006\\
# 100 &\textbf{0.478 $\pm$ 0.075} & 0.067 $\pm$ 0.011 & \textbf{0.466 $\pm$ 0.06} & 0.061 $\pm$ 0.004 & \textbf{0.079 $\pm$ 0.009} & 0.068 $\pm$ 0.004\\
# 500 &\textbf{0.22 $\pm$ 0.054} & 0.054 $\pm$ 0.005 & \textbf{0.286 $\pm$ 0.039} & 0.056 $\pm$ 0.003 & 0.052 $\pm$ 0.004 & \textbf{0.081 $\pm$ 0.005}*\\
# 1000 &\textbf{0.073 $\pm$ 0.006} & 0.065 $\pm$ 0.011 & \textbf{0.08 $\pm$ 0.008} & 0.05 $\pm$ 0.003 & 0.047 $\pm$ 0.004 & \textbf{0.084 $\pm$ 0.007}*\\
# 5000 &0.046 $\pm$ 0.003 & \textbf{0.06 $\pm$ 0.014} & 0.04 $\pm$ 0.003 & \textbf{0.044 $\pm$ 0.004} & 0.043 $\pm$ 0.003 & \textbf{0.094 $\pm$ 0.008}*\\
# 10000 &\textbf{0.048 $\pm$ 0.005} & 0.047 $\pm$ 0.005 & 0.041 $\pm$ 0.003 & \textbf{0.043 $\pm$ 0.004} & 0.042 $\pm$ 0.003 & \textbf{0.082 $\pm$ 0.012}*\\
# ################################################
# #
# # PLOT FIGURE
# #
# ################################################
